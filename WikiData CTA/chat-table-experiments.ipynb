# %%
import os
import re
import pickle
import numpy as np
from dotenv import dotenv_values
from langchain import PromptTemplate, LLMChain, OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.schema import SystemMessage, HumanMessage, AIMessage

# %%
config = dotenv_values("../.env")
os.environ['OPENAI_API_KEY'] = config["OPENAI_API_KEY"]
OPENAI_API_KEY = config["OPENAI_API_KEY"]

# %%
labels_to_text = {
    "soccer.football_league": "football league",
    "government.government_office_or_title": "government office or title",
    "organization.non_profit_organization": "non profit organization",
    "olympics.olympic_games": "olympic games",
    "cvg.cvg_genre": "cvg genre",
    "ice_hockey.hockey_position": "ice hockey position",
    "tv.tv_network": "tv network",
    "aviation.airline": "aviation airline",
    "american_football.football_conference": "american football conference",
    "soccer.football_world_cup": "football world cup",
    "american_football.football_coach": "american football coach",
    "military.military_unit": "military unit",
    "military.military_post": "military post",
    "music.media_format": "music media format",
    "tv.tv_personality": "tv personality",
    "baseball.baseball_team": "baseball team",
    "cvg.cvg_developer": "cvg developer",
    "soccer.football_award": "football award",
    "ice_hockey.hockey_team": "ice hockey team",
    "tv.tv_writer": "tv writer",
    "meteorology.tropical_cyclone_season": "tropical cyclone season",
    "soccer.fifa": "soccer fifa",
    "cvg.cvg_publisher": "cvg publisher",
    "baseball.baseball_player": "baseball player",
    "sports.sports_championship": "sports championship",
    "soccer.football_team_manager": "football team manager",
    "sports.golfer": "sports golfer",
    "baseball.baseball_position": "baseball position",
    "military.rank": "military rank",
    "sports.sports_championship": "sports championship",
    "cvg.cvg_platform": "cvg platform",
    "music.musical_group": "musical group",
    "amusement_parks.ride": "amusement parks ride",
    "music.genre": "music genre",
    "music.lyricist": "music lyricist",
    "music.record_label": "music record label",
    "meteorology.tropical_cyclone": "tropical cyclone",
    "aviation.airport": "airport"
}

# %%
text_to_label = {
    "football league": "soccer.football_league",
    "government office or title": "government.government_office_or_title",
    "non profit organization": "organization.non_profit_organization",
    "olympic games": "olympics.olympic_games",
    "cvg genre": "cvg.cvg_genre",
    "ice hockey position": "ice_hockey.hockey_position",
    "tv network": "tv.tv_network",
    "aviation airline": "aviation.airline",
    "american football conference": "american_football.football_conference",
    "football world cup": "soccer.football_world_cup",
    "american football coach": "american_football.football_coach",
    "military unit": "military.military_unit",
    "military post": "military.military_post",
    "music media format": "music.media_format",
    "tv personality": "tv.tv_personality",
    "baseball team": "baseball.baseball_team",
    "cvg developer": "cvg.cvg_developer",
    "football award": "soccer.football_award",
    "ice hockey team": "ice_hockey.hockey_team",
    "tv writer": "tv.tv_writer",
    "tropical cyclone season": "meteorology.tropical_cyclone_season",
    "soccer fifa": "soccer.fifa",
    "cvg publisher": "cvg.cvg_publisher",
    "baseball player": "baseball.baseball_player",
    "sports championship": "sports.sports_championship",
    "football team manager": "soccer.football_team_manager",
    "sports golfer": "sports.golfer",
    "baseball position": "baseball.baseball_position",
    "military rank": "military.rank",
    "cvg platform": "cvg.cvg_platform",
    "musical group": "music.musical_group",
    "amusement parks ride": "amusement_parks.ride",
    "music genre": "music.genre",
    "music lyricist": "music.lyricist",
    "music record label": "music.record_label",
    "tropical cyclone": "meteorology.tropical_cyclone",
    "airport": "aviation.airport"
}

# %% [markdown]
# ## Load test (and training) set

# %%
with open('wiki-cta-train-table.pkl', "rb") as f:
    train = pickle.load(f)
with open('wiki-cta-test-table.pkl', "rb") as f:
    test = pickle.load(f)

examples = [example[1] for example in test ]
labels =  [l for example in test for l in example[2]]

train_examples = [ example[1] for example in train ]
train_example_labels = []
for table in train:
    col_labels = """"""
    for i, l in enumerate(table[2]):
        col_labels += f"""Column {i+1}: {", ".join([labels_to_text[m] for m in l])}\n"""
    train_example_labels.append(col_labels.strip())

# %%
labels_joined = ", ".join([labels_to_text[l] for l in labels_to_text])
labels_joined
# Out:
# 'football league, government office or title, non profit organization, olympic games, cvg genre, ice hockey position, tv network, aviation airline, american football conference, football world cup, american football coach, military unit, military post, music media format, tv personality, baseball team, cvg developer, football award, ice hockey team, tv writer, tropical cyclone season, soccer fifa, cvg publisher, baseball player, sports championship, football team manager, sports golfer, baseball position, military rank, cvg platform, musical group, amusement parks ride, music genre, music lyricist, music record label, tropical cyclone, airport'

# %%
model_name = 'gpt-3.5-turbo-1106'
chat = ChatOpenAI(openai_api_key=OPENAI_API_KEY, temperature=0, model=model_name)

# %% [markdown]
# ## Choose setup: zero-shot, one-shot or five-shot

# %% [markdown]
# CTA TABLE

# %% [markdown]
# ZERO SHOT

# %%
#role
nr="zero"
prompt_name = "r"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))

    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role2
nr="zero"
prompt_name = "r2"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}. Answer with more than one label only if needed!"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}."))

    res = chat(messages)
    preds.append(res.content)

# %%
#role
nr="zero"
prompt_name = "r3"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Data Scientist, the best in your field and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))

    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
# role + instructions

nr="zero"
prompt_name = "r+i"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))

    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
# role + instructions

nr="zero"
prompt_name = "r+i2"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label from the label-set that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, use only the labels from the label-set and separate your responses with commas."))

    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)
# Out:
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised ServiceUnavailableError: The server is overloaded or not ready yet..

# %%
# role + instructions

nr="zero"
prompt_name = "r+i3"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content= "Your instructions are: 1. Review the provided input and organize it into a table format. 2. Carefully examine the values within each cell of the table. 3. For every column in the table, choose one label or more if needed, that best represents the meaning of the cells in that column. 4. Avoid duplicate labels when responding. Provide a single unique label, or if multiple, ensure they are distinct and follow the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...' 5. Ensure that your answer contains ONLY labels from the set and no additional text or characters."))
                                           
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
# role + instructions + step by step
nr="zero"
prompt_name = "r+i+s_b_s"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)
# Out:
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised ServiceUnavailableError: The server is overloaded or not ready yet..

# %%
# role + step by step + instructions
nr="zero"
prompt_name = "r+s_b_s+i"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
# role + instructions(step by step)
nr="zero"
prompt_name = "r+i(s_b_s)"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step. Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role + instructions + motivation
nr="zero"
prompt_name = "r+i+m"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role + motivation + instructions
nr="zero"
prompt_name = "r+m+i"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role + instructions + step by step + motivation
nr="zero"
prompt_name = "r+i+s_b_s+m"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + CONTEXT

nr="zero"
prompt_name = "r+i+c"

preds = []
for example in examples:
    messages = []

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Type Annotation is a sub-task of Table Annotation and refers to the process of identifying the semantic type of the values of a column in a table."))

    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + CONTEXT P2

nr="zero"
prompt_name = "r+i+c1"

preds = []
for example in examples:
    messages = []

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Type Annotation is a sub-task of Table Annotation and involves categorizing each column in a table based on its content."))

    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + CONTEXT P3
nr="zero"
prompt_name = "r+i+c2"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Type Annotation is a sub-task of Table Annotation and involves categorizing each column of a table based on its content.  Your task is the same, to analyze and then predict the column type with one or more of the provided labels from the label-set!")) 
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + CONTEXT (removing the word "CONTEXT")
nr="zero"
prompt_name = "r+i+c2.1"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"Column Type Annotation is a sub-task of Table Annotation and involves categorizing each column of a table based on its content.  Your task is the same, to analyze and then predict the column type with one or more of the provided labels from the label-set!")) 
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role + instructions + step by step + motivation + context
nr="zero"
prompt_name = "r+i+s_b_s+m+c"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))
    messages.append(SystemMessage(content=f"CONTEXT: Column Type Annotation is a sub-task of Table Annotation and involves categorizing each column of a table based on its content.  Your task is the same, to analyze and then predict the column type with one or more of the provided labels from the label-set!")) 
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role + instructions + context (example)
nr="zero"
prompt_name = "r+i+c.example"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"CONTEXT: Here is an example of how Column Type Annotation task is solved: 'Classify the given column: Columm1: Dog, Cat, Dog, parrot.'"
                                  "First check the values of Columm1: Dog, Cat, Dog, parrot"   
                                  "Carefully think and analyze the values, decide and predict the label that best fits"
                                  "Answer: Column 1 : animal, pet "))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role + instructions + context and (example)
nr="zero"
prompt_name = "r+i+c+example"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Type Annotation is a sub-task of Table Annotation and involves categorizing each column of a table based on its content.  Your task is the same, to analyze and then predict the column type with one or more of the provided labels from the label-set. Here is an example of how Column Type Annotation task is solved: 'Classify the given column: Columm1: Dog, Cat, Dog, parrot.'"
                                  "First check the values of Columm1: Dog, Cat, Dog, parrot"   
                                  "Carefully think and analyze the values, decide and predict the label that best fits"
                                  "Answer: Column 1 : animal, pet "))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
# Generating tables to use for "Generated Knowledge Prompt"  
import openai

generated_examples = []
generated_examples_labels = []

for label in labels:

    for table_number in range(1, 6):
        messages = []
        
        prompt = f"Generate 1 table with 4 random columns and 5 rows. Include one column about {label}. Please return only the values, no need to explain."

        messages.append({"role": "system", "content": prompt})
       
        response = openai.ChatCompletion.create(
            model='gpt-3.5-turbo-0301',
            messages=messages
        )
        
        generated_content = response['choices'][0]['message']['content'].strip()
        generated_examples.append(generated_content)
        generated_examples_labels.append(label)

# %%
""" file_name=f'GKP-Input/Generated-Tables.pkl'
f = open(file_name,'wb')
pickle.dump(generated_examples, f)
f.close() """

# %%
""" file_name=f'GKP-Input/Generated-Table-Labels.pkl'
f = open(file_name,'wb')
pickle.dump(generated_examples_labels, f)
f.close() """

# %%
with open(f'GKP-Input/Generated-Tables.pkl', "rb") as f:
    tables = pickle.load(f)
tables

# %%
with open(f'GKP-Input/Generated-Table-Labels.pkl', "rb") as f:
    labels = pickle.load(f)
labels

# %% [markdown]
# ONE SHOT

# %%
#role
import random 

nr="one"
prompt_name = "r"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))

    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
# role + instructions
import random 

nr="one"
prompt_name = "r+i"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))

    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
# role + instructions + step by step
import random

nr="one"
prompt_name = "r+i+s_b_s"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
# role + step by step + instructions
import random

nr="one"
prompt_name = "r+s_b_s+i"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role + instructions + motivation
import random 

nr="one"
prompt_name = "r+i+m"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))
    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role + motivation + instructions
import random 

nr="one"
prompt_name = "r+m+i"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role + instructions + step by step + motivation
import random

nr="one"
prompt_name = "r+i+s_b_s+m"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))
    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + CONTEXT P3
import random 

nr="one"
prompt_name = "r+i+c2"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Type Annotation is a sub-task of Table Annotation and involves categorizing each column of a table based on its content.  Your task is the same, to analyze and then predict the column type with one or more of the provided labels from the label-set!")) 
    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role + instructions + step by step + motivation + context
import random 

nr="one"
prompt_name = "r+i+s_b_s+m+c"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))
    messages.append(SystemMessage(content=f"CONTEXT: Column Type Annotation is a sub-task of Table Annotation and involves categorizing each column of a table based on its content.  Your task is the same, to analyze and then predict the column type with one or more of the provided labels from the label-set!")) 
    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role + instructions + context (example)
import random 

nr="one"
prompt_name = "r+i+c.example"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"CONTEXT: Here is an example of how Column Type Annotation task is solved: 'Classify the given column: Columm1: Dog, Cat, Dog, parrot.'"
                                  "First check the values of Columm1: Dog, Cat, Dog, parrot"   
                                  "Carefully think and analyze the values, decide and predict the label that best fits"
                                  "Answer: Column 1 : animal, pet "))
    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role + instructions + context and (example)
import random 

nr="one"
prompt_name = "r+i+c+example"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Type Annotation is a sub-task of Table Annotation and involves categorizing each column of a table based on its content.  Your task is the same, to analyze and then predict the column type with one or more of the provided labels from the label-set. Here is an example of how Column Type Annotation task is solved: 'Classify the given column: Columm1: Dog, Cat, Dog, parrot.'"
                                  "First check the values of Columm1: Dog, Cat, Dog, parrot"   
                                  "Carefully think and analyze the values, decide and predict the label that best fits"
                                  "Answer: Column 1 : animal, pet "))
    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
with open('GKP-Input/Generated-Tables.pkl', "rb") as f:
    train_tables = pickle.load(f)
with open('GKP-Input/Generated-Table-Labels.pkl', "rb") as f:
    train_labels = pickle.load(f)

# %%
#Role + instructions +  Generated Knowledge (GKP)
import random

nr="one"
prompt_name = "r+i+s_b_s+m+GKP"

preds = []
for example in examples:
    messages = []

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))
  
    index_gen = random.randint(0, len(train_tables)-1)
    messages.append(HumanMessage(content=f"This is an example of a table that includes a column with the label {train_labels[index_gen]}:\n{train_tables[index_gen]}"))
    index = random.randint(0, len(train_examples)-1)
    messages.append(SystemMessage(content=f" Classify these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))

     
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
messages
# Out:
# [SystemMessage(content='You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: football league, government office or title, non profit organization, olympic games, cvg genre, ice hockey position, tv network, aviation airline, american football conference, football world cup, american football coach, military unit, military post, music media format, tv personality, baseball team, cvg developer, football award, ice hockey team, tv writer, tropical cyclone season, soccer fifa, cvg publisher, baseball player, sports championship, football team manager, sports golfer, baseball position, military rank, cvg platform, musical group, amusement parks ride, music genre, music lyricist, music record label, tropical cyclone, airport.'),
#  SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."),
#  SystemMessage(content="Let's think step by step."),
#  SystemMessage(content='Your answer is very important. Take your time and think well before answering!'),
#  HumanMessage(content="This is an example of a table that includes a column with the label ['soccer.football_league']:\n| soccer.football_league | Column 1 | Column 2 | Column 3 |\n|-----------------------|----------|----------|----------|\n| Premier League         | value    | value    | value    |\n| La Liga                | value    | value    | value    |\n| Bundesliga            | value    | value    | value    |\n| Serie A                | value    | value    | value    |\n| MLS                    | value    | value    | value    |"),
#  SystemMessage(content=' Classify these table columns: Column 1 ||\nDivision 1 ||\nDivision 1 ||\nPro League ||\nPro League ||\nDivision 1'),
#  AIMessage(content='Column 1: football league'),
#  HumanMessage(content='Classify these table columns: Column 1 ||\nParlophone ||\nParlophone ||\nColumbia ||\nParlophone ||\nParlophone')]

# %%
#Role + instructions +  Generated Knowledge (GKP)
import random

nr="one"
prompt_name = "r+i+c2+GKP"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Type Annotation is a sub-task of Table Annotation and involves categorizing each column of a table based on its content.  Your task is the same, to analyze and then predict the column type with one or more of the provided labels from the label-set!")) 
  
    index_gen = random.randint(0, len(train_tables)-1)
    messages.append(HumanMessage(content=f"This is an example of a table that includes a column with the label {train_labels[index_gen]}:\n{train_tables[index_gen]}"))
    index = random.randint(0, len(train_examples)-1)
    messages.append(SystemMessage(content=f" Classify these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))

     
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %% [markdown]
# FIVE SHOT

# %%
# role + instructions
import random 

nr="five"
prompt_name = "r+i"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))

    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
# role + instructions + step by step
import random

nr="five"
prompt_name = "r+i+s_b_s"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role + instructions + motivation
import random 

nr="five"
prompt_name = "r+i+m"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))
    
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role + instructions + step by step + motivation
import random

nr="five"
prompt_name = "r+i+s_b_s+m"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))
    
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + CONTEXT P3
import random 

nr="five"
prompt_name = "r+i+c2"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Type Annotation is a sub-task of Table Annotation and involves categorizing each column of a table based on its content.  Your task is the same, to analyze and then predict the column type with one or more of the provided labels from the label-set!")) 
    
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#role + instructions + context and (example)
import random 

nr="five"
prompt_name = "r+i+c+example"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Type Annotation is a sub-task of Table Annotation and involves categorizing each column of a table based on its content.  Your task is the same, to analyze and then predict the column type with one or more of the provided labels from the label-set. Here is an example of how Column Type Annotation task is solved: 'Classify the given column: Columm1: Dog, Cat, Dog, parrot.'"
                                  "First check the values of Columm1: Dog, Cat, Dog, parrot"   
                                  "Carefully think and analyze the values, decide and predict the label that best fits"
                                  "Answer: Column 1 : animal, pet "))
    
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)
# Out:
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised ServiceUnavailableError: The server is overloaded or not ready yet..

# %%
with open('GKP-Input/Generated-Tables.pkl', "rb") as f:
    train_tables = pickle.load(f)
with open('GKP-Input/Generated-Table-Labels.pkl', "rb") as f:
    train_labels = pickle.load(f)

# %%
#Role + instructions +  Generated Knowledge (GKP)
import random

nr="five"
prompt_name = "r+i+c2+GKP"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the given columns of a table with one or more of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a label that best captures the overall meaning of the cells in that column. 4.Respond with your selected labels for each column, following the format: 'Column1: SelectedLabel, Column2: SelectedLabel, ...'. 5. Answer with more than one label for a column only if needed, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Type Annotation is a sub-task of Table Annotation and involves categorizing each column of a table based on its content.  Your task is the same, to analyze and then predict the column type with one or more of the provided labels from the label-set!")) 
  
    for i in range(0,5):
        index_gen = random.randint(0, len(train_tables)-1)
        messages.append(HumanMessage(content=f"This is an example of a table that includes a column with the label '{train_labels[index_gen]}':\n{train_tables[index_gen]}"))
        index = random.randint(0, len(train_examples)-1)
        messages.append(SystemMessage(content=f"Classify these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
preds

# %%
file_name=f'Predictions/{model_name}/table/{nr}-shot/chat-table-{prompt_name}-{nr}-shot.pkl'
f = open(file_name,'wb')
pickle.dump(preds,f)
f.close()

# %% [markdown]
# ## Evaluation

# %%
predictions = []
i=0
for j, table_preds in enumerate(preds):
   
    table_number = len(test[j][2])
    # print(j)
    
    if "Class:" in table_preds:
        table_preds = table_preds.split("Class:")[1]

    if ":\n" in table_preds:
        table_preds = table_preds.split(":\n")[1]
      

    if ":" in table_preds or "-" in table_preds:
        if ":" in table_preds:
            separator = ":"
            start = 1
            end = table_number+1
        else:
            separator = "-"  
            start = 1
            end = table_number+1
    else:
        separator = ","
        start = 0
        end = table_number

    # print(separator)
    # print(start)
    # print(end)
        
    col_preds = table_preds.split(separator)[start:end]
    # print(col_preds)
    
    for pred in col_preds:
        column_predictions = []
        i+=1
       
        if "," in pred:
            separator = ","

            multilabels = pred.split(separator)

            # print(multilabels)

            for multi in multilabels:
            
                if "\n" in multi:
                    multi = multi.split('\n')[0].strip()
                if "," in multi:
                    multi = multi.split(",")[0].strip()
                if '(' in multi:
                    multi = multi.split("(")[0].strip()
                if '.' in multi:
                    multi = multi.split(".")[0].strip()
                multi = multi.strip().lower()
                
                if multi in text_to_label:
                    column_predictions.append(text_to_label[multi])
                else:
                    print(f"For test example {i} out of label space prediction: {multi}")
                    column_predictions.append('-')

        else:

            if "\n" in pred:
                pred = pred.split('\n')[0].strip()
            if "," in pred:
                pred = pred.split(",")[0].strip()
            if '(' in pred:
                pred = pred.split("(")[0].strip()
            if '.' in pred:
                pred = pred.split(".")[0].strip()
            pred = pred.strip().lower()

            if pred in text_to_label:
                column_predictions.append(text_to_label[pred])
            else:
                print(f"For test example {i} out of label space prediction: {pred}")
                column_predictions.append('-')

        predictions.append(column_predictions)
        
    if len(col_preds) < table_number:
        for m in range(0, table_number-len(col_preds)):
            predictions.append(["-"]) #'-'
            i+=1
# Out:
# For test example 12 out of label space prediction: it seems like there might be a mistake in the input
# For test example 20 out of label space prediction: aviation airport
# For test example 39 out of label space prediction: it seems like there might be a mistake
# For test example 40 out of label space prediction: golf player
# For test example 40 out of label space prediction: column 2
# For test example 41 out of label space prediction: golf player
# For test example 45 out of label space prediction: baseball coach
# For test example 52 out of label space prediction: aviation airport
# For test example 56 out of label space prediction: it seems like there might be a misunderstanding
# For test example 77 out of label space prediction: baseball coach
# For test example 104 out of label space prediction: it seems like there might be a misunderstanding
# For test example 118 out of label space prediction: column 2
# For test example 152 out of label space prediction: column 2
# For test example 153 out of label space prediction: column 3
# For test example 162 out of label space prediction: government office
# For test example 167 out of label space prediction: it seems like there might be a misunderstanding
# For test example 177 out of label space prediction: baseball team manager
# For test example 179 out of label space prediction: baseball coach
# For test example 184 out of label space prediction: baseball manager
# For test example 217 out of label space prediction: baseball
# For test example 217 out of label space prediction: column 2
# For test example 218 out of label space prediction: column 3
# For test example 219 out of label space prediction: baseball
# For test example 220 out of label space prediction: it seems like there might be some confusion in the input
# For test example 222 out of label space prediction: i'm sorry
# For test example 227 out of label space prediction: baseball team manager
# For test example 230 out of label space prediction: college or university
# For test example 250 out of label space prediction: government office
# For test example 262 out of label space prediction: column 2
# For test example 263 out of label space prediction: column 3
# For test example 278 out of label space prediction: column 2
# For test example 294 out of label space prediction: it seems like there might be a misunderstanding
# For test example 301 out of label space prediction: i'm sorry
# For test example 303 out of label space prediction: column 2
# For test example 314 out of label space prediction: football score
# For test example 346 out of label space prediction: government office
# For test example 348 out of label space prediction: it seems like there might be a mistake in the input
# For test example 350 out of label space prediction: title
# For test example 360 out of label space prediction: i'm sorry
# For test example 365 out of label space prediction: college or university
# For test example 374 out of label space prediction: baseball team manager
# For test example 377 out of label space prediction: baseball team manager
# For test example 381 out of label space prediction: it seems like there might be a misunderstanding
# For test example 385 out of label space prediction: column 2
# For test example 390 out of label space prediction: i'm sorry
# For test example 422 out of label space prediction: column 2
# For test example 423 out of label space prediction: column 3
# For test example 431 out of label space prediction: baseball team manager
# For test example 436 out of label space prediction: column 2
# For test example 437 out of label space prediction: column 3
# For test example 467 out of label space prediction: soccer
# For test example 468 out of label space prediction: soccer
# For test example 479 out of label space prediction: column 2
# For test example 480 out of label space prediction: column 3
# For test example 481 out of label space prediction: column 4
# For test example 486 out of label space prediction: football manager
# For test example 518 out of label space prediction: baseball team manager
# For test example 526 out of label space prediction: column 2
# For test example 530 out of label space prediction: column 2
# For test example 533 out of label space prediction: it seems like there might be an error in the input
# For test example 541 out of label space prediction: baseball team manager
# For test example 543 out of label space prediction: music
# For test example 544 out of label space prediction: music
# For test example 549 out of label space prediction: i'm sorry
# For test example 554 out of label space prediction: football manager
# For test example 560 out of label space prediction: column 2
# For test example 561 out of label space prediction: column 3
# For test example 563 out of label space prediction: i'm sorry
# For test example 573 out of label space prediction: it seems like you've provided a list of tv networks
# For test example 593 out of label space prediction: government office
# For test example 594 out of label space prediction: government office
# For test example 596 out of label space prediction: this column does not fit any of the provided labels
# For test example 599 out of label space prediction: aviation airport
# For test example 612 out of label space prediction: i'm sorry
# For test example 613 out of label space prediction: column 2
# For test example 614 out of label space prediction: column 3
# For test example 633 out of label space prediction: university
# For test example 655 out of label space prediction: aviation airport
# For test example 672 out of label space prediction: i'm sorry
# For test example 684 out of label space prediction: aviation airport
# For test example 695 out of label space prediction: column 2
# For test example 696 out of label space prediction: column 3
# For test example 740 out of label space prediction: college/university
# For test example 742 out of label space prediction: college or university
# For test example 744 out of label space prediction: college or university
# For test example 755 out of label space prediction: baseball manager
# For test example 770 out of label space prediction: it seems like there might be an error in the input
# For test example 773 out of label space prediction: basketball league

# %%
predictions
# Out:
# [['soccer.football_league'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_team'],
#  ['soccer.football_team_manager', 'ice_hockey.hockey_position'],
#  ['baseball.baseball_player', 'american_football.football_coach'],
#  ['soccer.football_team_manager'],
#  ['ice_hockey.hockey_team'],
#  ['soccer.football_league'],
#  ['music.record_label'],
#  ['music.musical_group'],
#  ['sports.golfer'],
#  ['-'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_position'],
#  ['american_football.football_conference'],
#  ['sports.sports_championship', 'american_football.football_conference'],
#  ['soccer.football_league'],
#  ['sports.golfer'],
#  ['-'],
#  ['ice_hockey.hockey_team'],
#  ['tv.tv_personality'],
#  ['tv.tv_personality'],
#  ['tv.tv_personality'],
#  ['tv.tv_personality'],
#  ['soccer.football_league'],
#  ['tv.tv_network'],
#  ['baseball.baseball_player'],
#  ['soccer.football_league'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_player'],
#  ['soccer.football_award'],
#  ['soccer.football_award', 'sports.sports_championship'],
#  ['soccer.football_league'],
#  ['ice_hockey.hockey_team'],
#  ['soccer.football_league'],
#  ['-'],
#  ['-', '-'],
#  ['-'],
#  ['soccer.football_league'],
#  ['soccer.football_league', 'sports.sports_championship'],
#  ['baseball.baseball_team'],
#  ['-'],
#  ['baseball.baseball_player'],
#  ['sports.sports_championship'],
#  ['sports.sports_championship'],
#  ['cvg.cvg_developer'],
#  ['cvg.cvg_publisher'],
#  ['sports.golfer'],
#  ['-'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['soccer.football_league'],
#  ['-'],
#  ['soccer.football_league'],
#  ['music.genre'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_position'],
#  ['military.military_unit'],
#  ['music.record_label'],
#  ['tv.tv_network'],
#  ['tv.tv_network'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['tv.tv_network'],
#  ['-'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_player'],
#  ['sports.golfer'],
#  ['aviation.airline'],
#  ['aviation.airport'],
#  ['aviation.airport'],
#  ['ice_hockey.hockey_position'],
#  ['ice_hockey.hockey_team'],
#  ['tv.tv_writer'],
#  ['cvg.cvg_developer'],
#  ['cvg.cvg_developer'],
#  ['tv.tv_network'],
#  ['aviation.airport'],
#  ['tv.tv_personality'],
#  ['baseball.baseball_position'],
#  ['sports.sports_championship'],
#  ['soccer.football_league'],
#  ['cvg.cvg_developer'],
#  ['sports.golfer'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_position', 'soccer.football_team_manager'],
#  ['baseball.baseball_position'],
#  ['cvg.cvg_platform'],
#  ['military.rank'],
#  ['-'],
#  ['tv.tv_network'],
#  ['cvg.cvg_developer'],
#  ['cvg.cvg_platform'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['ice_hockey.hockey_position'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['ice_hockey.hockey_team'],
#  ['music.record_label'],
#  ['american_football.football_coach'],
#  ['military.military_unit'],
#  ['military.military_post'],
#  ['baseball.baseball_player', '-'],
#  ['baseball.baseball_team'],
#  ['tv.tv_personality'],
#  ['government.government_office_or_title'],
#  ['soccer.football_league'],
#  ['aviation.airline'],
#  ['olympics.olympic_games'],
#  ['soccer.football_league'],
#  ['baseball.baseball_player'],
#  ['sports.golfer'],
#  ['sports.golfer'],
#  ['american_football.football_coach'],
#  ['soccer.football_league'],
#  ['tv.tv_network'],
#  ['tv.tv_network'],
#  ['aviation.airline'],
#  ['baseball.baseball_position'],
#  ['sports.golfer'],
#  ['sports.golfer'],
#  ['sports.golfer'],
#  ['aviation.airport'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_team'],
#  ['soccer.football_award'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['soccer.football_league'],
#  ['baseball.baseball_position', '-'],
#  ['baseball.baseball_player', '-'],
#  ['baseball.baseball_team'],
#  ['tv.tv_network'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['meteorology.tropical_cyclone_season'],
#  ['meteorology.tropical_cyclone_season'],
#  ['soccer.football_world_cup'],
#  ['soccer.football_world_cup'],
#  ['-'],
#  ['tv.tv_personality'],
#  ['soccer.football_league'],
#  ['soccer.football_award'],
#  ['soccer.football_league'],
#  ['-'],
#  ['ice_hockey.hockey_team'],
#  ['aviation.airport'],
#  ['government.government_office_or_title'],
#  ['ice_hockey.hockey_team'],
#  ['military.military_unit'],
#  ['military.military_post'],
#  ['ice_hockey.hockey_position'],
#  ['soccer.football_league'],
#  ['tv.tv_personality'],
#  ['-'],
#  ['baseball.baseball_player'],
#  ['-'],
#  ['soccer.football_league'],
#  ['music.musical_group'],
#  ['music.lyricist'],
#  ['tv.tv_personality'],
#  ['-'],
#  ['military.military_unit', 'military.military_post'],
#  ['soccer.football_league'],
#  ['olympics.olympic_games'],
#  ['music.musical_group'],
#  ['soccer.football_team_manager'],
#  ['soccer.football_team_manager'],
#  ['tv.tv_network'],
#  ['amusement_parks.ride'],
#  ['amusement_parks.ride'],
#  ['amusement_parks.ride'],
#  ['soccer.football_league'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_team'],
#  ['ice_hockey.hockey_position'],
#  ['tv.tv_network'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['cvg.cvg_developer'],
#  ['tv.tv_personality'],
#  ['tv.tv_personality'],
#  ['tv.tv_personality'],
#  ['sports.golfer'],
#  ['sports.golfer'],
#  ['sports.golfer'],
#  ['aviation.airport'],
#  ['soccer.football_league'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_team'],
#  ['sports.sports_championship'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['-', '-'],
#  ['baseball.baseball_player', '-'],
#  ['-'],
#  ['-'],
#  ['american_football.football_coach'],
#  ['-'],
#  ['amusement_parks.ride'],
#  ['aviation.airport'],
#  ['tv.tv_network'],
#  ['baseball.baseball_player'],
#  ['-'],
#  ['ice_hockey.hockey_position'],
#  ['ice_hockey.hockey_position'],
#  ['-'],
#  ['sports.golfer'],
#  ['sports.sports_championship'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['soccer.football_team_manager'],
#  ['american_football.football_coach'],
#  ['military.rank'],
#  ['music.musical_group', 'music.lyricist'],
#  ['sports.golfer'],
#  ['sports.golfer'],
#  ['sports.golfer'],
#  ['sports.sports_championship'],
#  ['baseball.baseball_team'],
#  ['tv.tv_network'],
#  ['soccer.football_league', 'soccer.football_team_manager'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_position'],
#  ['soccer.football_league'],
#  ['baseball.baseball_player'],
#  ['-'],
#  ['tv.tv_network'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['sports.golfer'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['music.musical_group'],
#  ['music.record_label'],
#  ['music.media_format'],
#  ['baseball.baseball_position', '-'],
#  ['baseball.baseball_player', '-'],
#  ['baseball.baseball_team'],
#  ['sports.golfer'],
#  ['tv.tv_network'],
#  ['soccer.football_league'],
#  ['sports.golfer'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['soccer.football_league'],
#  ['meteorology.tropical_cyclone_season'],
#  ['tv.tv_personality'],
#  ['baseball.baseball_team'],
#  ['soccer.football_league'],
#  ['aviation.airport'],
#  ['baseball.baseball_player', '-'],
#  ['baseball.baseball_team'],
#  ['soccer.fifa'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['music.media_format'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_position'],
#  ['music.record_label'],
#  ['aviation.airport'],
#  ['soccer.football_league'],
#  ['aviation.airport'],
#  ['-'],
#  ['music.musical_group'],
#  ['tv.tv_personality'],
#  ['ice_hockey.hockey_team'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['soccer.football_league'],
#  ['-'],
#  ['soccer.football_league'],
#  ['meteorology.tropical_cyclone', '-'],
#  ['meteorology.tropical_cyclone_season'],
#  ['ice_hockey.hockey_position'],
#  ['ice_hockey.hockey_position'],
#  ['tv.tv_network'],
#  ['aviation.airport'],
#  ['soccer.football_league'],
#  ['sports.golfer'],
#  ['baseball.baseball_team'],
#  ['music.media_format'],
#  ['soccer.football_league'],
#  ['-'],
#  ['music.media_format'],
#  ['music.record_label'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['tv.tv_personality'],
#  ['tv.tv_personality'],
#  ['military.military_unit'],
#  ['ice_hockey.hockey_team'],
#  ['american_football.football_coach'],
#  ['baseball.baseball_player'],
#  ['american_football.football_coach'],
#  ['baseball.baseball_team'],
#  ['aviation.airline'],
#  ['soccer.football_league'],
#  ['military.rank'],
#  ['music.lyricist'],
#  ['military.military_unit'],
#  ['baseball.baseball_position'],
#  ['soccer.football_league'],
#  ['sports.golfer'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_player'],
#  ['soccer.football_league'],
#  ['tv.tv_network'],
#  ['soccer.football_league'],
#  ['olympics.olympic_games'],
#  ['-'],
#  ['military.rank'],
#  ['-'],
#  ['sports.golfer'],
#  ['-'],
#  ['soccer.football_league'],
#  ['music.musical_group'],
#  ['music.musical_group'],
#  ['tv.tv_personality'],
#  ['tv.tv_personality'],
#  ['music.record_label'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['-'],
#  ['sports.golfer'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_player'],
#  ['ice_hockey.hockey_position'],
#  ['-'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['soccer.football_league'],
#  ['baseball.baseball_team'],
#  ['-'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['-'],
#  ['aviation.airport'],
#  ['aviation.airline'],
#  ['sports.golfer'],
#  ['-'],
#  ['sports.golfer'],
#  ['tv.tv_personality'],
#  ['military.military_unit'],
#  ['cvg.cvg_developer', '-'],
#  ['cvg.cvg_publisher'],
#  ['sports.golfer'],
#  ['soccer.football_league'],
#  ['ice_hockey.hockey_team'],
#  ['-'],
#  ['soccer.football_league'],
#  ['cvg.cvg_developer'],
#  ['cvg.cvg_platform'],
#  ['aviation.airport'],
#  ['soccer.football_league'],
#  ['sports.golfer'],
#  ['music.record_label'],
#  ['sports.sports_championship'],
#  ['music.record_label'],
#  ['music.media_format'],
#  ['ice_hockey.hockey_team'],
#  ['ice_hockey.hockey_position'],
#  ['music.record_label'],
#  ['soccer.football_league'],
#  ['military.military_unit'],
#  ['soccer.football_league'],
#  ['soccer.football_award'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['cvg.cvg_platform'],
#  ['baseball.baseball_team'],
#  ['olympics.olympic_games'],
#  ['military.military_unit'],
#  ['cvg.cvg_platform'],
#  ['olympics.olympic_games'],
#  ['olympics.olympic_games'],
#  ['sports.golfer', '-'],
#  ['sports.golfer', '-'],
#  ['sports.golfer'],
#  ['ice_hockey.hockey_team'],
#  ['tv.tv_network'],
#  ['aviation.airport'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_position'],
#  ['-'],
#  ['baseball.baseball_player'],
#  ['tv.tv_network'],
#  ['tv.tv_network'],
#  ['tv.tv_personality'],
#  ['baseball.baseball_position', '-'],
#  ['baseball.baseball_player', '-'],
#  ['baseball.baseball_team'],
#  ['sports.golfer'],
#  ['soccer.football_league'],
#  ['ice_hockey.hockey_position'],
#  ['ice_hockey.hockey_team'],
#  ['ice_hockey.hockey_team'],
#  ['ice_hockey.hockey_team'],
#  ['olympics.olympic_games'],
#  ['tv.tv_personality'],
#  ['tv.tv_personality'],
#  ['tv.tv_network'],
#  ['amusement_parks.ride'],
#  ['music.lyricist'],
#  ['music.record_label'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_position'],
#  ['cvg.cvg_genre'],
#  ['cvg.cvg_platform'],
#  ['cvg.cvg_developer'],
#  ['cvg.cvg_genre'],
#  ['cvg.cvg_platform'],
#  ['cvg.cvg_developer'],
#  ['music.media_format'],
#  ['sports.sports_championship'],
#  ['soccer.football_league'],
#  ['tv.tv_network'],
#  ['soccer.football_league'],
#  ['baseball.baseball_player'],
#  ['-'],
#  ['-'],
#  ['sports.sports_championship'],
#  ['music.musical_group'],
#  ['music.musical_group'],
#  ['music.musical_group'],
#  ['soccer.football_league'],
#  ['music.record_label'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_team'],
#  ['soccer.football_league'],
#  ['sports.golfer'],
#  ['baseball.baseball_player', '-'],
#  ['baseball.baseball_team', '-'],
#  ['baseball.baseball_player', '-'],
#  ['baseball.baseball_team'],
#  ['soccer.football_league'],
#  ['music.record_label'],
#  ['sports.golfer'],
#  ['-'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['cvg.cvg_developer'],
#  ['cvg.cvg_genre'],
#  ['soccer.football_league'],
#  ['cvg.cvg_genre'],
#  ['cvg.cvg_platform'],
#  ['baseball.baseball_team'],
#  ['ice_hockey.hockey_team', 'sports.sports_championship'],
#  ['soccer.football_league'],
#  ['tv.tv_network'],
#  ['soccer.football_league'],
#  ['sports.golfer'],
#  ['sports.golfer'],
#  ['baseball.baseball_player'],
#  ['olympics.olympic_games'],
#  ['soccer.football_league'],
#  ['sports.sports_championship'],
#  ['sports.sports_championship'],
#  ['cvg.cvg_developer'],
#  ['cvg.cvg_publisher'],
#  ['cvg.cvg_platform'],
#  ['soccer.football_league'],
#  ['sports.golfer'],
#  ['soccer.football_league'],
#  ['music.record_label'],
#  ['sports.golfer'],
#  ['olympics.olympic_games'],
#  ['tv.tv_network'],
#  ['military.rank'],
#  ['military.military_unit'],
#  ['-'],
#  ['military.military_unit'],
#  ['military.rank'],
#  ['tv.tv_network'],
#  ['meteorology.tropical_cyclone_season'],
#  ['soccer.football_world_cup'],
#  ['music.genre'],
#  ['ice_hockey.hockey_team'],
#  ['soccer.football_team_manager', '-'],
#  ['soccer.football_league'],
#  ['sports.sports_championship'],
#  ['tv.tv_network'],
#  ['cvg.cvg_developer', '-'],
#  ['cvg.cvg_publisher'],
#  ['soccer.football_league'],
#  ['-'],
#  ['tv.tv_network'],
#  ['military.military_unit'],
#  ['sports.golfer'],
#  ['sports.golfer'],
#  ['cvg.cvg_developer'],
#  ['music.media_format'],
#  ['music.record_label'],
#  ['-'],
#  ['aviation.airport'],
#  ['-'],
#  ['-'],
#  ['sports.golfer'],
#  ['american_football.football_coach'],
#  ['soccer.football_league'],
#  ['music.genre'],
#  ['-'],
#  ['soccer.football_league'],
#  ['ice_hockey.hockey_position'],
#  ['soccer.football_league'],
#  ['sports.golfer'],
#  ['-'],
#  ['soccer.football_league', 'sports.sports_championship'],
#  ['ice_hockey.hockey_position'],
#  ['music.genre'],
#  ['tv.tv_personality'],
#  ['soccer.football_league'],
#  ['baseball.baseball_position', '-'],
#  ['baseball.baseball_player', '-'],
#  ['baseball.baseball_team'],
#  ['-'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['soccer.football_league'],
#  ['soccer.football_world_cup'],
#  ['cvg.cvg_developer'],
#  ['military.military_unit'],
#  ['-'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['cvg.cvg_genre'],
#  ['tv.tv_network'],
#  ['soccer.football_league'],
#  ['aviation.airport'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['sports.golfer'],
#  ['-', 'military.rank'],
#  ['-'],
#  ['sports.golfer'],
#  ['-'],
#  ['soccer.football_league'],
#  ['american_football.football_coach'],
#  ['-'],
#  ['music.genre'],
#  ['music.genre'],
#  ['music.musical_group'],
#  ['amusement_parks.ride'],
#  ['amusement_parks.ride'],
#  ['amusement_parks.ride'],
#  ['ice_hockey.hockey_team'],
#  ['aviation.airport'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['soccer.football_league'],
#  ['-'],
#  ['baseball.baseball_position', '-'],
#  ['baseball.baseball_player', '-'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['ice_hockey.hockey_position'],
#  ['ice_hockey.hockey_position'],
#  ['ice_hockey.hockey_position'],
#  ['ice_hockey.hockey_team'],
#  ['ice_hockey.hockey_position'],
#  ['soccer.football_team_manager'],
#  ['ice_hockey.hockey_position'],
#  ['ice_hockey.hockey_team'],
#  ['ice_hockey.hockey_position'],
#  ['-'],
#  ['ice_hockey.hockey_position'],
#  ['ice_hockey.hockey_team'],
#  ['sports.golfer'],
#  ['military.military_unit'],
#  ['military.military_post'],
#  ['military.rank'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['cvg.cvg_platform'],
#  ['tv.tv_network'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_team'],
#  ['soccer.football_team_manager'],
#  ['military.military_post'],
#  ['music.media_format'],
#  ['sports.golfer'],
#  ['government.government_office_or_title'],
#  ['soccer.football_league'],
#  ['-'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['aviation.airport'],
#  ['tv.tv_network'],
#  ['military.rank'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['government.government_office_or_title'],
#  ['music.record_label'],
#  ['government.government_office_or_title'],
#  ['music.genre'],
#  ['music.genre'],
#  ['cvg.cvg_developer'],
#  ['cvg.cvg_platform'],
#  ['olympics.olympic_games'],
#  ['baseball.baseball_team'],
#  ['-'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['music.musical_group'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['ice_hockey.hockey_team'],
#  ['music.musical_group'],
#  ['ice_hockey.hockey_position'],
#  ['soccer.football_team_manager'],
#  ['military.military_unit'],
#  ['baseball.baseball_team'],
#  ['-'],
#  ['baseball.baseball_player'],
#  ['military.military_unit'],
#  ['soccer.football_league'],
#  ['cvg.cvg_publisher'],
#  ['cvg.cvg_platform'],
#  ['military.military_unit'],
#  ['cvg.cvg_developer'],
#  ['cvg.cvg_publisher'],
#  ['ice_hockey.hockey_position'],
#  ['soccer.football_league'],
#  ['music.lyricist', '-'],
#  ['music.musical_group', '-'],
#  ['music.lyricist'],
#  ['music.musical_group'],
#  ['military.rank'],
#  ['soccer.football_league'],
#  ['ice_hockey.hockey_team'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['music.media_format'],
#  ['sports.golfer'],
#  ['ice_hockey.hockey_team'],
#  ['cvg.cvg_developer'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['military.military_unit'],
#  ['american_football.football_coach'],
#  ['baseball.baseball_team'],
#  ['ice_hockey.hockey_team'],
#  ['soccer.football_award'],
#  ['music.musical_group'],
#  ['music.record_label'],
#  ['soccer.football_team_manager'],
#  ['ice_hockey.hockey_position'],
#  ['cvg.cvg_developer'],
#  ['soccer.football_league'],
#  ['tv.tv_network'],
#  ['soccer.football_league'],
#  ['tv.tv_network'],
#  ['sports.golfer'],
#  ['military.military_unit'],
#  ['soccer.football_league', 'sports.sports_championship'],
#  ['military.military_unit'],
#  ['sports.golfer'],
#  ['baseball.baseball_player'],
#  ['ice_hockey.hockey_team'],
#  ['ice_hockey.hockey_team'],
#  ['soccer.football_league'],
#  ['meteorology.tropical_cyclone_season'],
#  ['music.media_format'],
#  ['music.lyricist'],
#  ['music.lyricist'],
#  ['ice_hockey.hockey_position'],
#  ['-'],
#  ['ice_hockey.hockey_position'],
#  ['-'],
#  ['ice_hockey.hockey_position'],
#  ['-'],
#  ['aviation.airline'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_position'],
#  ['soccer.football_league'],
#  ['baseball.baseball_team'],
#  ['tv.tv_network'],
#  ['tv.tv_network'],
#  ['tv.tv_network'],
#  ['baseball.baseball_team'],
#  ['-'],
#  ['ice_hockey.hockey_team'],
#  ['soccer.football_league'],
#  ['cvg.cvg_publisher'],
#  ['cvg.cvg_publisher'],
#  ['ice_hockey.hockey_position'],
#  ['soccer.football_team_manager'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_player', 'soccer.football_team_manager'],
#  ['sports.sports_championship'],
#  ['sports.golfer'],
#  ['sports.golfer'],
#  ['-'],
#  ['tv.tv_network'],
#  ['amusement_parks.ride'],
#  ['soccer.football_league', '-'],
#  ['soccer.football_league'],
#  ['tv.tv_network'],
#  ['soccer.football_league'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_team'],
#  ['soccer.football_league'],
#  ['cvg.cvg_platform'],
#  ['ice_hockey.hockey_team'],
#  ['aviation.airport'],
#  ['soccer.football_league'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_position'],
#  ['baseball.baseball_player'],
#  ['baseball.baseball_team'],
#  ['baseball.baseball_position'],
#  ['cvg.cvg_developer'],
#  ['cvg.cvg_platform'],
#  ['sports.golfer'],
#  ['sports.golfer'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['soccer.football_league'],
#  ['baseball.baseball_team'],
#  ['music.record_label']]

# %% [markdown]
# ### Calculate Precision, Recall, Macro-F1 and Micro-F1

# %%
def calculate_f1_scores(y_tests, y_preds, num_classes, types):

    # print(y_tests)
    # print(y_preds)

    #y_tests = [types.index(y) for y in y_tests]
    y_tests = [[types.index(l) for l in y] for y in y_tests]
    #print(y_tests)
    # y_preds = [types.index(y) for y in y_preds]
    y_preds = [[types.index(l) for l in y] for y in y_preds]
    #y_preds = [types.index(y[0]) if isinstance(y, list) else types.index(y) for y in y_preds]
    
    # print(len(y_tests))
    # print(len(y_preds))

    # print(y_tests)
    # print(y_preds)
    
    cm = np.zeros(shape=(num_classes,num_classes))
    
    # for i in range(len(y_tests)):
    #     cm[y_preds[i]][y_tests[i]] += 1

    for i, labels in enumerate(y_tests):
        # print(labels)
        for label in labels:
            if label not in y_preds[i]:
                cm[-1][label] += 1 #FN
                # print("FN")
                # print(f'{label} not in {y_preds[i]}')
            else:
                cm[label][label] += 1 #TP
                # print("TP")
                # print(f'{label} in {y_preds[i]}')

    for i, labels in enumerate(y_preds):
        # print(labels)
        for label in labels:
            if label not in y_tests[i]:
                cm[label][-1] += 1 #FP
                # print("FP")
                # print(f'{label} not in {y_tests[i]}')

        
    report = {}
    
    for j in range(len(cm[0])):
        report[j] = {}
        report[j]['FN'] = 0
        report[j]['FP'] = 0
        report[j]['TP'] = cm[j][j]

        for i in range(len(cm)):
            if i != j:
                report[j]['FN'] += cm[i][j]
        for k in range(len(cm[0])):
            if k != j:
                report[j]['FP'] += cm[j][k]

        precision = report[j]['TP'] / (report[j]['TP'] + report[j]['FP'])
        recall = report[j]['TP'] / (report[j]['TP'] + report[j]['FN'])
        f1 = 2*precision*recall / (precision + recall)
        
        if np.isnan(f1):
            f1 = 0
        if np.isnan(precision):
            f1 = 0
        if np.isnan(recall):
            f1 = 0

        report[j]['p'] =  precision
        report[j]['r'] =  recall
        report[j]['f1'] = f1
    
    all_fn = 0
    all_tp = 0
    all_fp = 0

    for r in report:
        if r != num_classes-1:
            all_fn += report[r]['FN']
            all_tp += report[r]['TP']
            all_fp += report[r]['FP']
        
    class_f1s = [ report[class_]['f1'] for class_ in report]
    class_p = [ 0 if np.isnan(report[class_]['p']) else report[class_]['p'] for class_ in report]
    class_r = [ 0 if np.isnan(report[class_]['r']) else report[class_]['r'] for class_ in report]
    macro_f1 = sum(class_f1s[:-1]) / (num_classes-1)
    
    p =  sum(class_p[:-1]) / (num_classes-1)
    r =  sum(class_r[:-1]) / (num_classes-1)
    micro_f1 = all_tp / ( all_tp + (1/2 * (all_fp + all_fn) )) 
    
    per_class_eval = {}
    for index, t in enumerate(types[:-1]):
        per_class_eval[t] = {"Precision":class_p[index], "Recall": class_r[index], "F1": class_f1s[index]}
    
    evaluation = {
        "Micro-F1": micro_f1,
        "Macro-F1": macro_f1,
        "Precision": p,
        "Recall": r
    }
    
    return [ evaluation, per_class_eval]

# %%
list_set_labels = list(labels_to_text.keys())
types = list_set_labels
types = types + ["-"] if ["-"] in predictions else types
evaluation, per_class_eval = calculate_f1_scores(labels, predictions, len(types), types)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_3580\2882399176.py:60: RuntimeWarning: invalid value encountered in scalar divide
#   precision = report[j]['TP'] / (report[j]['TP'] + report[j]['FP'])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_3580\2882399176.py:61: RuntimeWarning: invalid value encountered in scalar divide
#   recall = report[j]['TP'] / (report[j]['TP'] + report[j]['FN'])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_3580\2882399176.py:62: RuntimeWarning: invalid value encountered in scalar divide
#   f1 = 2*precision*recall / (precision + recall)

# %%
evaluation
# Out:
# {'Micro-F1': 0.8467336683417085,
#  'Macro-F1': 0.7015641487854963,
#  'Precision': 0.7623236129572815,
#  'Recall': 0.739265090577459}

# %%
per_class_eval
# Out:
# {'soccer.football_league': {'Precision': 0.9454545454545454,
#   'Recall': 0.9454545454545454,
#   'F1': 0.9454545454545454},
#  'government.government_office_or_title': {'Precision': 0.9,
#   'Recall': 0.9,
#   'F1': 0.9},
#  'organization.non_profit_organization': {'Precision': 0,
#   'Recall': 0,
#   'F1': 0},
#  'olympics.olympic_games': {'Precision': 1.0,
#   'Recall': 0.7142857142857143,
#   'F1': 0.8333333333333333},
#  'cvg.cvg_genre': {'Precision': 1.0, 'Recall': 0.5, 'F1': 0.6666666666666666},
#  'ice_hockey.hockey_position': {'Precision': 0.9285714285714286,
#   'Recall': 0.8125,
#   'F1': 0.8666666666666666},
#  'tv.tv_network': {'Precision': 0.972972972972973,
#   'Recall': 0.9230769230769231,
#   'F1': 0.9473684210526315},
#  'aviation.airline': {'Precision': 0.6666666666666666,
#   'Recall': 1.0,
#   'F1': 0.8},
#  'american_football.football_conference': {'Precision': 1.0,
#   'Recall': 0.2,
#   'F1': 0.33333333333333337},
#  'soccer.football_world_cup': {'Precision': 0.25,
#   'Recall': 0.5,
#   'F1': 0.3333333333333333},
#  'american_football.football_coach': {'Precision': 0.7777777777777778,
#   'Recall': 0.7777777777777778,
#   'F1': 0.7777777777777778},
#  'military.military_unit': {'Precision': 0.8888888888888888,
#   'Recall': 0.8888888888888888,
#   'F1': 0.8888888888888888},
#  'military.military_post': {'Precision': 0.4,
#   'Recall': 1.0,
#   'F1': 0.5714285714285715},
#  'music.media_format': {'Precision': 0.375,
#   'Recall': 1.0,
#   'F1': 0.5454545454545454},
#  'tv.tv_personality': {'Precision': 1.0,
#   'Recall': 0.6060606060606061,
#   'F1': 0.7547169811320755},
#  'baseball.baseball_team': {'Precision': 0.989010989010989,
#   'Recall': 0.9574468085106383,
#   'F1': 0.972972972972973},
#  'cvg.cvg_developer': {'Precision': 0.95,
#   'Recall': 0.6785714285714286,
#   'F1': 0.7916666666666667},
#  'soccer.football_award': {'Precision': 0.8333333333333334,
#   'Recall': 0.3125,
#   'F1': 0.45454545454545453},
#  'ice_hockey.hockey_team': {'Precision': 0.9705882352941176,
#   'Recall': 0.7857142857142857,
#   'F1': 0.8684210526315789},
#  'tv.tv_writer': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'meteorology.tropical_cyclone_season': {'Precision': 0.2,
#   'Recall': 1.0,
#   'F1': 0.33333333333333337},
#  'soccer.fifa': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'cvg.cvg_publisher': {'Precision': 0.875,
#   'Recall': 0.4375,
#   'F1': 0.5833333333333334},
#  'baseball.baseball_player': {'Precision': 0.96875,
#   'Recall': 0.8532110091743119,
#   'F1': 0.9073170731707316},
#  'sports.sports_championship': {'Precision': 0.13043478260869565,
#   'Recall': 1.0,
#   'F1': 0.23076923076923078},
#  'soccer.football_team_manager': {'Precision': 0.5,
#   'Recall': 1.0,
#   'F1': 0.6666666666666666},
#  'sports.golfer': {'Precision': 0.9649122807017544,
#   'Recall': 0.9649122807017544,
#   'F1': 0.9649122807017544},
#  'baseball.baseball_position': {'Precision': 0.9772727272727273,
#   'Recall': 1.0,
#   'F1': 0.9885057471264368},
#  'military.rank': {'Precision': 0.9, 'Recall': 1.0, 'F1': 0.9473684210526316},
#  'cvg.cvg_platform': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'music.musical_group': {'Precision': 0.46153846153846156,
#   'Recall': 0.9230769230769231,
#   'F1': 0.6153846153846155},
#  'amusement_parks.ride': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'music.genre': {'Precision': 0.8333333333333334,
#   'Recall': 0.7142857142857143,
#   'F1': 0.7692307692307692},
#  'music.lyricist': {'Precision': 0.6, 'Recall': 0.2, 'F1': 0.3},
#  'music.record_label': {'Precision': 0.9166666666666666,
#   'Recall': 0.8461538461538461,
#   'F1': 0.8799999999999999},
#  'meteorology.tropical_cyclone': {'Precision': 0.5,
#   'Recall': 1.0,
#   'F1': 0.6666666666666666},
#  'aviation.airport': {'Precision': 1.0,
#   'Recall': 0.8928571428571429,
#   'F1': 0.9433962264150945}}

# %% [markdown]
# ## Error Analysis

# %%
errors = 0
for i in range(len(predictions)):
    label_set = set(labels[i]) # if isinstance(labels[i], list) else {labels[i]}
    
    prediction_set = set(predictions[i]) #.split(', ')
    
    # if not label_set.intersection(prediction_set):
    if len(list(label_set-prediction_set) + list(prediction_set-label_set)) != 0:
        for y in label_set:
            if y not in prediction_set:
                errors +=1
        print(f"Predicted as {predictions[i]} when it was {label_set}")
errors
# Out:
# Predicted as ['soccer.football_team_manager', 'ice_hockey.hockey_team'] when it was {'cvg.cvg_genre'}
# Predicted as ['baseball.baseball_player', '-'] when it was {'baseball.baseball_player'}
# Predicted as ['baseball.baseball_team', 'american_football.football_coach'] when it was {'baseball.baseball_team'}
# Predicted as ['-'] when it was {'ice_hockey.hockey_position'}
# Predicted as ['baseball.baseball_player', '-'] when it was {'baseball.baseball_player'}
# Predicted as ['baseball.baseball_team', '-'] when it was {'baseball.baseball_team'}
# Predicted as ['sports.sports_championship'] when it was {'american_football.football_conference'}
# Predicted as ['ice_hockey.hockey_team', '-'] when it was {'ice_hockey.hockey_team'}
# Predicted as ['tv.tv_personality', '-'] when it was {'tv.tv_personality'}
# Predicted as ['tv.tv_personality', '-'] when it was {'tv.tv_personality'}
# Predicted as ['tv.tv_personality', '-'] when it was {'tv.tv_personality'}
# Predicted as ['soccer.football_league'] when it was {'soccer.fifa'}
# Predicted as ['baseball.baseball_player'] when it was {'american_football.football_coach'}
# Predicted as ['sports.sports_championship'] when it was {'soccer.football_award'}
# Predicted as ['baseball.baseball_team', '-'] when it was {'baseball.baseball_team'}
# Predicted as ['sports.sports_championship'] when it was {'american_football.football_conference'}
# Predicted as ['cvg.cvg_publisher'] when it was {'cvg.cvg_developer', 'cvg.cvg_publisher'}
# Predicted as ['baseball.baseball_player', '-'] when it was {'baseball.baseball_player'}
# Predicted as ['cvg.cvg_developer'] when it was {'cvg.cvg_developer', 'cvg.cvg_publisher'}
# Predicted as ['military.rank'] when it was {'soccer.football_league'}
# Predicted as ['cvg.cvg_developer'] when it was {'cvg.cvg_developer', 'cvg.cvg_publisher'}
# Predicted as ['baseball.baseball_position', 'soccer.football_team_manager'] when it was {'baseball.baseball_position'}
# Predicted as ['-'] when it was {'tv.tv_network'}
# Predicted as ['-'] when it was {'tv.tv_network'}
# Predicted as ['cvg.cvg_developer'] when it was {'cvg.cvg_developer', 'cvg.cvg_publisher'}
# Predicted as ['military.military_post'] when it was {'military.military_unit'}
# Predicted as ['soccer.football_league'] when it was {'soccer.football_award'}
# Predicted as ['cvg.cvg_developer'] when it was {'cvg.cvg_publisher'}
# Predicted as ['baseball.baseball_player'] when it was {'tv.tv_personality', 'baseball.baseball_player'}
# Predicted as ['baseball.baseball_player', '-'] when it was {'baseball.baseball_player'}
# Predicted as ['-'] when it was {'baseball.baseball_player'}
# Predicted as ['baseball.baseball_position', '-'] when it was {'baseball.baseball_position'}
# Predicted as ['baseball.baseball_player', '-'] when it was {'baseball.baseball_player'}
# Predicted as ['sports.sports_championship'] when it was {'olympics.olympic_games'}
# Predicted as ['meteorology.tropical_cyclone_season'] when it was {'olympics.olympic_games'}
# Predicted as ['soccer.football_world_cup'] when it was {'olympics.olympic_games'}
# Predicted as ['soccer.football_world_cup'] when it was {'olympics.olympic_games'}
# Predicted as ['government.government_office_or_title'] when it was {'tv.tv_personality'}
# Predicted as ['soccer.football_team_manager', 'soccer.football_award'] when it was {'soccer.football_league'}
# Predicted as ['soccer.football_league'] when it was {'soccer.football_award'}
# Predicted as ['sports.sports_championship'] when it was {'cvg.cvg_genre'}
# Predicted as ['military.military_post'] when it was {'aviation.airport', 'military.military_post'}
# Predicted as ['music.musical_group'] when it was {'tv.tv_personality', 'music.lyricist'}
# Predicted as ['music.lyricist', 'music.record_label'] when it was {'tv.tv_personality', 'music.lyricist'}
# Predicted as ['-'] when it was {'baseball.baseball_player'}
# Predicted as ['military.military_unit', 'military.military_post'] when it was {'military.military_unit'}
# Predicted as ['-', '-'] when it was {'soccer.football_team_manager'}
# Predicted as ['-'] when it was {'soccer.football_team_manager'}
# Predicted as ['sports.sports_championship'] when it was {'baseball.baseball_team'}
# Predicted as ['music.record_label'] when it was {'cvg.cvg_publisher', 'music.record_label'}
# Predicted as ['ice_hockey.hockey_position', '-'] when it was {'ice_hockey.hockey_position'}
# Predicted as ['-'] when it was {'ice_hockey.hockey_team'}
# Predicted as ['sports.golfer', '-'] when it was {'sports.golfer'}
# Predicted as ['baseball.baseball_position', '-'] when it was {'baseball.baseball_position'}
# Predicted as ['music.musical_group', 'music.lyricist'] when it was {'music.musical_group'}
# Predicted as ['sports.sports_championship'] when it was {'ice_hockey.hockey_team'}
# Predicted as ['-'] when it was {'baseball.baseball_player'}
# Predicted as ['music.media_format'] when it was {'music.record_label'}
# Predicted as ['sports.sports_championship'] when it was {'cvg.cvg_genre'}
# Predicted as ['-'] when it was {'tv.tv_personality'}
# Predicted as ['music.lyricist'] when it was {'tv.tv_personality', 'music.lyricist'}
# Predicted as ['meteorology.tropical_cyclone', '-'] when it was {'meteorology.tropical_cyclone'}
# Predicted as ['sports.sports_championship'] when it was {'cvg.cvg_genre'}
# Predicted as ['music.media_format'] when it was {'music.record_label'}
# Predicted as ['music.musical_group'] when it was {'music.lyricist'}
# Predicted as ['soccer.football_league'] when it was {'soccer.fifa'}
# Predicted as ['tv.tv_personality'] when it was {'tv.tv_personality', 'music.lyricist'}
# Predicted as ['-', '-'] when it was {'government.government_office_or_title'}
# Predicted as ['music.musical_group'] when it was {'music.genre'}
# Predicted as ['music.musical_group'] when it was {'music.genre'}
# Predicted as ['sports.golfer', '-'] when it was {'tv.tv_personality'}
# Predicted as ['baseball.baseball_position', '-'] when it was {'baseball.baseball_position'}
# Predicted as ['baseball.baseball_player', '-'] when it was {'baseball.baseball_player'}
# Predicted as ['-'] when it was {'ice_hockey.hockey_team'}
# Predicted as ['-'] when it was {'baseball.baseball_player'}
# Predicted as ['-'] when it was {'baseball.baseball_player'}
# Predicted as ['cvg.cvg_publisher'] when it was {'cvg.cvg_developer', 'cvg.cvg_publisher'}
# Predicted as ['cvg.cvg_developer'] when it was {'cvg.cvg_developer', 'cvg.cvg_publisher'}
# Predicted as ['music.genre'] when it was {'music.record_label'}
# Predicted as ['soccer.football_award'] when it was {'soccer.football_award', 'soccer.football_league'}
# Predicted as ['baseball.baseball_position', '-'] when it was {'baseball.baseball_position'}
# Predicted as ['baseball.baseball_player', '-'] when it was {'baseball.baseball_player'}
# Predicted as ['sports.golfer', '-'] when it was {'sports.golfer'}
# Predicted as ['sports.golfer', '-'] when it was {'sports.golfer'}
# Predicted as ['american_football.football_coach'] when it was {'baseball.baseball_player'}
# Predicted as ['-'] when it was {'baseball.baseball_player'}
# Predicted as ['organization.non_profit_organization'] when it was {'ice_hockey.hockey_team'}
# Predicted as ['sports.sports_championship'] when it was {'tv.tv_personality'}
# Predicted as ['baseball.baseball_player', '-'] when it was {'baseball.baseball_player'}
# Predicted as ['baseball.baseball_team', '-'] when it was {'baseball.baseball_team'}
# Predicted as ['music.media_format'] when it was {'music.record_label'}
# Predicted as ['sports.sports_championship'] when it was {'soccer.football_league'}
# Predicted as ['sports.sports_championship'] when it was {'tv.tv_personality'}
# Predicted as ['soccer.football_league', 'sports.sports_championship'] when it was {'soccer.football_award'}
# Predicted as ['cvg.cvg_developer', '-'] when it was {'cvg.cvg_developer', 'cvg.cvg_publisher'}
# Predicted as ['sports.sports_championship'] when it was {'ice_hockey.hockey_team'}
# Predicted as ['aviation.airline'] when it was {'soccer.football_league'}
# Predicted as ['-'] when it was {'baseball.baseball_player'}
# Predicted as ['soccer.football_league', 'soccer.football_award'] when it was {'soccer.football_league'}
# Predicted as ['sports.sports_championship'] when it was {'ice_hockey.hockey_team'}
# Predicted as ['sports.sports_championship'] when it was {'ice_hockey.hockey_team'}
# Predicted as ['cvg.cvg_publisher'] when it was {'cvg.cvg_developer', 'cvg.cvg_publisher'}
# Predicted as ['military.military_unit'] when it was {'cvg.cvg_developer'}
# Predicted as ['meteorology.tropical_cyclone_season'] when it was {'soccer.football_world_cup', 'soccer.football_award'}
# Predicted as ['soccer.football_world_cup'] when it was {'soccer.football_world_cup', 'soccer.football_award'}
# Predicted as ['baseball.baseball_player'] when it was {'american_football.football_coach'}
# Predicted as ['-'] when it was {'ice_hockey.hockey_team'}
# Predicted as ['soccer.football_league'] when it was {'american_football.football_conference'}
# Predicted as ['sports.sports_championship', 'soccer.football_league'] when it was {'american_football.football_conference'}
# Predicted as ['cvg.cvg_publisher'] when it was {'cvg.cvg_developer', 'cvg.cvg_publisher'}
# Predicted as ['american_football.football_coach'] when it was {'tv.tv_personality'}
# Predicted as ['sports.golfer', 'sports.sports_championship'] when it was {'ice_hockey.hockey_team'}
# Predicted as ['-'] when it was {'baseball.baseball_player'}
# Predicted as ['music.musical_group'] when it was {'music.lyricist'}
# Predicted as ['music.genre'] when it was {'music.lyricist'}
# Predicted as ['soccer.football_league', 'sports.sports_championship'] when it was {'soccer.football_league'}
# Predicted as ['sports.sports_championship'] when it was {'soccer.football_award'}
# Predicted as ['baseball.baseball_team', '-'] when it was {'baseball.baseball_team'}
# Predicted as ['sports.sports_championship'] when it was {'soccer.football_award'}
# Predicted as ['-', '-'] when it was {'government.government_office_or_title'}
# Predicted as ['-'] when it was {'government.government_office_or_title'}
# Predicted as ['music.musical_group'] when it was {'music.lyricist'}
# Predicted as ['baseball.baseball_team', '-'] when it was {'baseball.baseball_team'}
# Predicted as ['-'] when it was {'baseball.baseball_player'}
# Predicted as ['-'] when it was {'ice_hockey.hockey_team'}
# Predicted as ['-'] when it was {'ice_hockey.hockey_team'}
# Predicted as ['-'] when it was {'ice_hockey.hockey_team'}
# Predicted as ['military.military_unit', '-'] when it was {'military.military_unit'}
# Predicted as ['military.military_post'] when it was {'aviation.airport'}
# Predicted as ['military.military_post'] when it was {'aviation.airport', 'military.military_post'}
# Predicted as ['tv.tv_network'] when it was {'music.record_label'}
# Predicted as ['baseball.baseball_player', '-'] when it was {'baseball.baseball_player'}
# Predicted as ['cvg.cvg_developer'] when it was {'cvg.cvg_developer', 'cvg.cvg_publisher'}
# Predicted as ['-'] when it was {'music.lyricist'}
# Predicted as ['sports.sports_championship'] when it was {'ice_hockey.hockey_team'}
# Predicted as ['baseball.baseball_position'] when it was {'sports.golfer'}
# Predicted as ['cvg.cvg_developer'] when it was {'cvg.cvg_publisher'}
# Predicted as ['cvg.cvg_publisher'] when it was {'cvg.cvg_developer', 'cvg.cvg_publisher'}
# Predicted as ['music.media_format'] when it was {'music.record_label'}
# Predicted as ['-'] when it was {'ice_hockey.hockey_position'}
# Predicted as ['cvg.cvg_developer'] when it was {'cvg.cvg_developer', 'cvg.cvg_publisher'}
# Predicted as ['soccer.football_league', 'sports.sports_championship'] when it was {'soccer.football_award', 'soccer.football_league'}
# Predicted as ['military.military_unit'] when it was {'soccer.football_league'}
# Predicted as ['-'] when it was {'tv.tv_personality'}
# Predicted as ['music.media_format'] when it was {'music.musical_group'}
# Predicted as ['tv.tv_writer'] when it was {'music.lyricist'}
# Predicted as ['music.musical_group'] when it was {'music.lyricist'}
# Predicted as ['-'] when it was {'ice_hockey.hockey_team'}
# Predicted as ['baseball.baseball_player'] when it was {'baseball.baseball_team'}
# Predicted as ['-'] when it was {'baseball.baseball_player'}
# Predicted as ['cvg.cvg_publisher'] when it was {'cvg.cvg_developer'}
# Predicted as ['cvg.cvg_publisher'] when it was {'cvg.cvg_developer', 'cvg.cvg_publisher'}
# Predicted as ['soccer.football_world_cup'] when it was {'soccer.football_award'}
# Predicted as ['-'] when it was {'baseball.baseball_player'}
# Predicted as ['-'] when it was {'cvg.cvg_genre'}
# Predicted as ['-'] when it was {'baseball.baseball_player'}
# 124

# %%
errors = 0
for i in range(len(predictions)):
    label_set = set(labels[i])
    prediction_set = set(predictions[i])
    
    if not label_set.issubset(prediction_set):
        errors += 1
        print(f"Predicted as {predictions[i]} when it was {label_set}")

print(errors)

# %% [markdown]
# ### Re-load previous preds files

# %%
with open(f'Predictions/{model_name}/table/{nr}-shot/chat-table-{prompt_name}-{nr}-shot.pkl', "rb") as f:
    preds = pickle.load(f)

# %%
preds
