# %%
import os
import re
import pickle
import numpy as np
from dotenv import dotenv_values
from langchain import PromptTemplate, LLMChain, OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.schema import SystemMessage, HumanMessage, AIMessage

# %%
config = dotenv_values("../.env")
os.environ['OPENAI_API_KEY'] = config["OPENAI_API_KEY"]
OPENAI_API_KEY = config["OPENAI_API_KEY"]

# %%
labels_to_text = {
    "datePublished": "date published",
    "isbn": "isbn",
    "numberOfPages": "number of pages",
    "worstRating": "worst rating",
    "priceCurrency": "price currency",
    "publisher": "publisher",
    "author": "author",
    "bookFormat": "book format",
    "inLanguage": "in language",
    "ratingValue": "rating value",
    "description": "description",
    "price": "price",
    "image": "image",
    "url": "url",
    "availability": "availability",
    "genre": "genre",
    "bestRating": "best rating",
    "itemCondition": "item condition",
    "review": "review",
    "startDate": "start date",
    "endDate": "end date",
    "location": "location",
    "validFrom": "valid from",
    "eventStatus": "event status",
    "eventAttendanceMode": "event attendance mode",
    "organizer": "organizer",
    "category": "category",
    "validThrough": "valid through",
    "telephone": "telephone",
    "duration": "duration",
    "email": "email",
    "streetAddress": "street address",
    "addressRegion": "region of address",
    "addressLocality": "locality of address",
    "priceRange": "price range",
    "postalCode": "postal code",
    "addressCountry": "address country",
    "faxNumber": "fax number",
    "dateCreated": "date created",
    "director": "director",
    "contentRating": "content rating",
    "actor": "actor",
    "inAlbum": "in album",
    "byArtist": "by artist",
    "jobTitle": "job title",
    "birthDate": "birth date",
    "gender": "gender",
    "nationality": "nationality",
    "weight": "weight",
    "releaseDate": "release date",
    "copyrightYear": "copyright year",
    "bookEdition": "book edition",
    "headline": "headline",
    "text": "text",
    "address": "address",
    "performer": "performer",
    "longitude": "longitude",
    "latitude": "latitude",
    "currenciesAccepted": "currencies accepted",
    "checkoutTime": "checkout time",
    "checkInTime": "check-in time",
    "amenityFeature": "amenity feature",
    "paymentAccepted": "payment accepted",
    "availableLanguage": "available language",
    "brand": "brand",
    "openingHours": "opening hours",
    "datePosted": "date posted",
    "employmentType": "employment type",
    "hiringOrganization": "hiring organization",
    "opens": "opens",
    "dayOfWeek": "day of week",
    "closes": "closes",
    "productionCompany": "production company",
    "countryOfOrigin": "country of origin",
    "numTracks": "number of tracks",
    "track": "track",
    "givenName": "given name",
    "familyName": "family name",
    "birthPlace": "birth place",
    "honorificSuffix": "honorific suffix",
    "alumniOf": "alumni of",
    "deathDate": "death date",
    "measurements": "measurements",
    "unitCode": "unit code",
    "productID": "product ID",
    "unitText": "unit text",
    "availableDeliveryMethod": "available delivery method",
    "model": "model",
    "manufacturer": "manufacturer",
    "color": "color",
    "gtin": "gtin",
    "material": "material",
    "servingSize": "serving size",
    "recipeInstructions": "recipe instructions",
    "recipeIngredient": "recipe ingredient",
    "cookTime": "cook time",
    "prepTime": "prep time",
    "totalTime": "total time",
    "nutrition": "nutrition",
    "recipeCategory": "recipe category",
    "recipeCuisine": "recipe cuisine",
    "cookingMethod": "cooking method",
    "suitableForDiet": "suitable for diet",
    "servesCuisine": "serves cuisine",
    "awayTeam": "away team",
    "homeTeam": "home team",
    "partOfSeries": "part of series",
    "episodeNumber": "episode number"
}

# %%
text_to_label = {
    "date published": "datePublished",
    "isbn": "isbn",
    "number of pages": "numberOfPages",
    "worst rating": "worstRating",
    "price currency": "priceCurrency",
    "publisher": "publisher",
    "author": "author",
    "book format": "bookFormat",
    "in language": "inLanguage",
    "rating value": "ratingValue",
    "description": "description",
    "price": "priceRange",
    "image": "image",
    "url": "url",
    "availability": "availability",
    "genre": "genre",
    "best rating": "bestRating",
    "item condition": "itemCondition",
    "review": "review",
    "start date": "startDate",
    "end date": "endDate",
    "location": "location",
    "valid from": "validFrom",
    "event status": "eventStatus",
    "event attendance mode": "eventAttendanceMode",
    "organizer": "organizer",
    "category": "category",
    "valid through": "validThrough",
    "telephone": "telephone",
    "duration": "duration",
    "email": "email",
    "street address": "streetAddress",
    "region of address": "addressRegion",
    "locality of address": "addressLocality",
    "price range": "priceRange",
    "postal code": "postalCode",
    "address country": "addressCountry",
    "fax number": "faxNumber",
    "date created": "dateCreated",
    "director": "director",
    "content rating": "contentRating",
    "actor": "actor",
    "in album": "inAlbum",
    "by artist": "byArtist",
    "job title": "jobTitle",
    "birth date": "birthDate",
    "gender": "gender",
    "nationality": "nationality",
    "weight": "weight",
    "release date": "releaseDate",
    "copyright year": "copyrightYear",
    "book edition": "bookEdition",
    "headline": "headline",
    "text": "text",
    "address": "address",
    "performer": "performer",
    "longitude": "longitude",
    "latitude": "latitude",
    "currencies accepted": "currenciesAccepted",
    "checkout time": "checkoutTime",
    "check-in time": "checkInTime",
    "amenity feature": "amenityFeature",
    "payment accepted": "paymentAccepted",
    "available language": "availableLanguage",
    "brand": "brand",
    "opening hours": "openingHours",
    "date posted": "datePosted",
    "employment type": "employmentType",
    "hiring organization": "hiringOrganization",
    "opens": "opens",
    "day of week": "dayOfWeek",
    "closes": "closes",
    "production company": "productionCompany",
    "country of origin": "countryOfOrigin",
    "number of tracks": "numTracks",
    "track": "track",
    "given name": "givenName",
    "family name": "familyName",
    "birth place": "birthPlace",
    "honorific suffix": "honorificSuffix",
    "alumni of": "alumniOf",
    "death date": "deathDate",
    "measurements": "measurements",
    "unit code": "unitCode",
    "product ID": "productID",
    "unit text": "unitText",
    "available delivery method": "availableDeliveryMethod",
    "model": "model",
    "manufacturer": "manufacturer",
    "color": "color",
    "gtin": "gtin",
    "material": "material",
    "serving size": "servingSize",
    "recipe instructions": "recipeInstructions",
    "recipe ingredient": "recipeIngredient",
    "cook time": "cookTime",
    "prep time": "prepTime",
    "total time": "totalTime",
    "nutrition": "nutrition",
    "recipe category": "recipeCategory",
    "recipe cuisine": "recipeCuisine",
    "cooking method": "cookingMethod",
    "suitable for diet": "suitableForDiet",
    "serves cuisine": "servesCuisine",
    "away team": "awayTeam",
    "home team": "homeTeam",
    "part of series": "partOfSeries",
    "episode number": "episodeNumber"
}

# %% [markdown]
# ## Load test (and training) set

# %%
with open('sotabv2-cpa-train-table.pkl', "rb") as f:
    train = pickle.load(f)
with open('sotabv2-cpa-sample-test-table.pkl', "rb") as f:
    test = pickle.load(f)

examples = [example[1] for example in test ]
labels = [l for example in test for l in example[2]]

train_examples = [ example[1] for example in train ]
train_example_labels = []
for table in train:
    col_labels = """"""
    for i, l in enumerate(table[2]):
        col_labels += f"""Column {i+2}: {labels_to_text[l]}\n"""
    train_example_labels.append(col_labels.strip())

# %%
len(train)
# Out:
# 29158

# %%
len(test)
# Out:
# 125

# %%
labels_joined = ", ".join([labels_to_text[label] for label in list(set(labels))]) 
labels_joined
# Out:
# 'recipe cuisine, author, family name, away team, closes, part of series, prep time, gender, honorific suffix, production company, available language, opens, organizer, unit code, recipe instructions, brand, copyright year, cooking method, in album, street address, cook time, best rating, currencies accepted, unit text, director, image, measurements, hiring organization, day of week, publisher, price range, genre, telephone, worst rating, weight, available delivery method, postal code, serves cuisine, book format, nationality, product ID, birth date, birth place, given name, price currency, start date, by artist, nutrition, locality of address, number of tracks, latitude, job title, total time, death date, category, suitable for diet, book edition, text, employment type, opening hours, date created, release date, payment accepted, longitude, valid through, duration, content rating, number of pages, description, event status, home team, price, headline, date published, manufacturer, rating value, amenity feature, alumni of, in language, check-in time, checkout time, url, gtin, color, recipe ingredient, actor, date posted, availability, isbn, event attendance mode, episode number, track, country of origin, address country, recipe category, fax number, review, end date, address, location, model, email, performer, valid from, region of address, item condition, material, serving size'

# %%
model_name = 'gpt-3.5-turbo-1106'
chat = ChatOpenAI(openai_api_key=OPENAI_API_KEY, temperature=0, model=model_name)

# %% [markdown]
# ## Choose setup: zero-shot, one-shot or five-shot

# %% [markdown]
# ZERO SHOT CPA TABLE

# %%
#ROLE
nr="zero"
#prompt_name = "r"  #two columns ...
prompt_name = "r1"  #two or more ...

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between two or more columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}. Answer with ONLY ONE of the labels from the provided label-set! Notice, you must not classify Column 1!"))
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))

    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE
nr="zero"
prompt_name = "r2"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between two or more columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}. Answer with ONLY ONE of the labels from the provided label-set for each column! Notice, you must not classify Column 1"))

    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE
nr="zero"
prompt_name = "r3"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to predict the relationship between the first column with the rest of the columns from a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}. Notice, do not annotate Column 1"))

    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE
nr="zero"
prompt_name = "r4"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table, note that you must not annotate Column 1 and must annotate the rest with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}."))

    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE
nr="zero"
prompt_name = "r5"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to identify the correlation of each column with the initial column in the table and label these relations with ONLY ONE of the following labels that are separated with a comma: {labels_joined}."))
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}."))

    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS
nr="zero"
prompt_name = "r+i"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table, note that you must not annotate Column 1 and must annotate the rest with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 5. Ensure that you use only one label from the provided set for each column, and separate your responses with commas."))

    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS
nr="zero"
prompt_name = "r2+i2"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))

    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS
nr="zero"
prompt_name = "r+i2"   #1+2

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table, note that you must not annotate Column 1 and must annotate the rest with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))

    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + StepByStep
nr="zero"
prompt_name = "r2+i2+s_b_s"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)
# Out:
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised ServiceUnavailableError: The server is overloaded or not ready yet..

# %%
#ROLE + StepByStep + INSTRUCTIONS
nr="zero"
prompt_name = "r2+s_b_s+i2"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + StepByStep
nr="zero"
prompt_name = "r2+i2+s_b_s.1"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step. Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + MOTIVATION
nr="zero"
prompt_name = "r2+i2+m"

preds = []
for example in examples:
   messages = []
    
   messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
   messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
   messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))

    
   messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
   res = chat(messages)
   preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + StepByStep + MOTIVATION
nr="zero"
prompt_name = "r2+i2+s_b_s+m"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))
   
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + StepByStep + MOTIVATION  P2
nr="zero"
prompt_name = "r+i2+s_b_s+m.1"


preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step. Your answer is very important. Take your time and think well before answering!"))
    
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + StepByStep + MOTIVATION + INSTRUCTIONS 
nr="zero"
prompt_name = "r+s_b_s+m+i2"


preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step. Your answer is very important. Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))

    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)
# Out:
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised ServiceUnavailableError: The server is overloaded or not ready yet..

# %%
#ROLE + INSTRUCTIONS (StepByStep, motivation) 
nr="zero"
#prompt_name = "r+i2(sbs-m)"
prompt_name = "r+i2(sbs-m)2"


preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    #messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas. 7. Let's think step by step. 8. Note, your answer is very important. Take your time and think well before answering!"))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5. Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas. Do not explain your answer. 7. Let's think step by step. 8. Note, your answer is very important. Take your time and think well before answering!"))


    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS (motivation) 
nr="zero"
prompt_name = "r+i2(m)"


preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas. 7. Your answer is very important. Take your time and think well before answering!"))

    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + MOTIVATION 
nr="zero"
#prompt_name = "r1+m"
prompt_name = "r2+m"


preds = []
for example in examples:
    messages = []
    
    #messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table, note that you must not annotate Column 1 and must annotate the rest with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))

    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + MOTIVATION + INSTRUCTIONS 
nr="zero"
prompt_name = "r+m+i2"


preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering! Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))

    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + CONTEXT
nr="zero"
prompt_name = "r+c"


preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Property Annotation is a sub-task of Table Annotation and refers to predicting the semantic relation between two or more columns."))

    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + CONTEXT
nr="zero"
prompt_name = "r+c1"


preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Property Annotation is a sub-task of Table Annotation and refers to predicting the semantic relation between two or more columns. You have the same task, you are required to label the columns of a given table, aiming to identify the correlation of each column with the initial column in the table."))

    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS(MOTIVATION) + CONTEXT
nr="zero"
prompt_name = "r+i2(m)+c1"


preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas. 7. Your answer is very important. Take your time and think well before answering!"))
    messages.append(SystemMessage(content=f"CONTEXT: Column Property Annotation is a sub-task of Table Annotation and refers to predicting the semantic relation between two or more columns. You have the same task, you are required to label the columns of a given table, aiming to identify the correlation of each column with the initial column in the table."))

    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + (StepByStep)INSTRUCTIONS + CONTEXT
nr="zero"
prompt_name = "r2+i2+s_b_s.1+c1"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step. Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Property Annotation is a sub-task of Table Annotation and refers to predicting the semantic relation between two or more columns. You have the same task, you are required to label the columns of a given table, aiming to identify the correlation of each column with the initial column in the table."))

    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS(MOTIVATION) + CONTEXT + EXAMPLE
nr="zero"
prompt_name = "r+i2(m)+c.example"


preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas. 7. Your answer is very important. Take your time and think well before answering!"))
    messages.append(SystemMessage(content=f"CONTEXT: Column Property Annotation is a sub-task of Table Annotation and refers to predicting the semantic relation between two or more columns. You have the same task, here is an example how you could solve a CPA task: 'Classify the relationship between these table columns: Columm1: Dog, Cat, Dog.  Column2: lis, moli, brauni. '"
                                  "First we check Columm1: Dog, Cat, Dog."   
                                  "Now we check Column2: lis, moli, brauni. Analyze Column 2 in relation to Column 1. Predict the relation between Column 2 and Column 1"
                                  "Answer: Column 2: pet names"))

    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
# Generating tables to use for "Generated Knowledge Prompt"  
import openai

generated_examples = []
generated_examples_labels = []

for label in labels:

    for table_number in range(1, 6):
        messages = []
        
        prompt = f"Generate 1 table with 4 random columns and 5 rows. Include one column about {label} and one of the other columns to be related to the {label}. Please return only the values, no need to explain."

        messages.append({"role": "system", "content": prompt})
       
        response = openai.ChatCompletion.create(
            model='gpt-3.5-turbo-0301',
            messages=messages
        )
        
        generated_content = response['choices'][0]['message']['content'].strip()
        generated_examples.append(generated_content)
        generated_examples_labels.append(label)

# %%
""" file_name=f'GKP-Input/Generated-Tables.pkl'
f = open(file_name,'wb')
pickle.dump(generated_examples, f)
f.close() """

# %%
""" file_name=f'GKP-Input/Generated-Table-Labels.pkl'
f = open(file_name,'wb')
pickle.dump(generated_examples_labels, f)
f.close() """

# %%
with open(f'GKP-Input/Generated-Tables.pkl', "rb") as f:
    tables = pickle.load(f)
tables

# %%
with open(f'GKP-Input/Generated-Table-Labels.pkl', "rb") as f:
    labels = pickle.load(f)
labels

# %% [markdown]
# ONE SHOT CPA TABLE

# %%
import random
#One-shot table + instructions + roles   #NOT M

nr="one"
prompt_name = "r1+i"

preds = []
for example in examples:
    messages = []
    

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between two or more columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}. Notice, you must not classify Column 1!"))
    messages.append(SystemMessage(content="Your instructions are: 1. Look at the input given to you and make a table out of it. 2. Look at the cell values in detail. 3. For each column, select a relationship that best represents the relationship between that column and the first column of the table. 4. Answer with only one selected relationship for each column with the format Column2: relationship. Don't return any relationship for the first column! 5. Answer only with labels from the provided label set!"))
 
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)
# Out:
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-1106 in organization org-JnRe4IF9kM1kFkJzhKlurHyV on tokens per min (TPM): Limit 60000, Used 58585, Requested 1711. Please try again in 296ms. Visit https://platform.openai.com/account/rate-limits to learn more..

# %%
#ROLE
import random 

nr="one"
prompt_name = "r2"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between two or more columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE
import random 

nr="one"
prompt_name = "r3"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to predict the relationship between the first column with the rest of the columns from a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE
import random 

nr="one"
prompt_name = "r4"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table, note that you must not annotate Column 1 and must annotate the rest with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS
import random

nr="one"
prompt_name = "r2+i2"

preds = []
for example in examples:
    messages = []
    

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))

    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + StepByStep
import random

nr="one"
prompt_name = "r2+i2+s_b_s"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + StepByStep + INSTRUCTIONS
import random

nr="one"
prompt_name = "r2+s_b_s+i2"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    
    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + StepByStep
import random

nr="one"
prompt_name = "r2+i2+s_b_s.1"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step. Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))

    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + MOTIVATION
import random

nr="one"
prompt_name = "r2+i2+m"

preds = []
for example in examples:
    messages = []
     
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))

    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + StepByStep + MOTIVATION
import random

nr="one"
prompt_name = "r2+i2+s_b_s+m"

preds = []
for example in examples:
    messages = []
     
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))

    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + StepByStep + MOTIVATION + INSTRUCTIONS 
import random

nr="one"
prompt_name = "r+s_b_s+m+i2"

preds = []
for example in examples:
    messages = []
     
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step. Your answer is very important. Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))

    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS (motivation) 
import random

nr="one"
prompt_name = "r+i2(m)"

preds = []
for example in examples:
    messages = []
     
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas. 7. Your answer is very important. Take your time and think well before answering!"))
    
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + CONTEXT
import random

nr="one"
prompt_name = "r+c1"

preds = []
for example in examples:
    messages = []

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Property Annotation is a sub-task of Table Annotation and refers to predicting the semantic relation between two or more columns. You have the same task, you are required to label the columns of a given table, aiming to identify the correlation of each column with the initial column in the table."))

   
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)
# Out:
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised APIError: Bad gateway. {"error":{"code":502,"message":"Bad gateway.","param":null,"type":"cf_bad_gateway"}} 502 {'error': {'code': 502, 'message': 'Bad gateway.', 'param': None, 'type': 'cf_bad_gateway'}} {'Date': 'Fri, 26 Jan 2024 19:02:44 GMT', 'Content-Type': 'application/json', 'Content-Length': '84', 'Connection': 'keep-alive', 'X-Frame-Options': 'SAMEORIGIN', 'Referrer-Policy': 'same-origin', 'Cache-Control': 'private, max-age=0, no-store, no-cache, must-revalidate, post-check=0, pre-check=0', 'Expires': 'Thu, 01 Jan 1970 00:00:01 GMT', 'Server': 'cloudflare', 'CF-RAY': '84bb0300cee22c0f-STR', 'alt-svc': 'h3=":443"; ma=86400'}.

# %%
#ROLE + INSTRUCTIONS(MOTIVATION) + CONTEXT
import random

nr="one"
prompt_name = "r+i2(m)+c1"

preds = []
for example in examples:
    messages = []
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas. 7. Your answer is very important. Take your time and think well before answering!"))
    messages.append(SystemMessage(content=f"CONTEXT: Column Property Annotation is a sub-task of Table Annotation and refers to predicting the semantic relation between two or more columns. You have the same task, you are required to label the columns of a given table, aiming to identify the correlation of each column with the initial column in the table."))
     
   
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + (StepByStep)INSTRUCTIONS + CONTEXT
import random

nr="one"
prompt_name = "r2+i2+s_b_s.1+c1"

preds = []
for example in examples:
    messages = []

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step. Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Property Annotation is a sub-task of Table Annotation and refers to predicting the semantic relation between two or more columns. You have the same task, you are required to label the columns of a given table, aiming to identify the correlation of each column with the initial column in the table."))
     
   
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS(MOTIVATION) + CONTEXT + EXAMPLE
import random

nr="one"
prompt_name = "r+i2(m)+c.example"

preds = []
for example in examples:
    messages = []

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas. 7. Your answer is very important. Take your time and think well before answering!"))
    messages.append(SystemMessage(content=f"CONTEXT: Column Property Annotation is a sub-task of Table Annotation and refers to predicting the semantic relation between two or more columns. You have the same task, here is an example how you could solve a CPA task: 'Classify the relationship between these table columns: Columm1: Dog, Cat, Dog.  Column2: lis, moli, brauni. '"
                                  "First we check Columm1: Dog, Cat, Dog."   
                                  "Now we check Column2: lis, moli, brauni. Analyze Column 2 in relation to Column 1. Predict the relation between Column 2 and Column 1"
                                  "Answer: Column 2: pet names"))
   
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)
# Out:
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600).

# %%
#ROLE + (StepByStep)INSTRUCTIONS + EXAMPLE CONTEXT
import random

nr="one"
prompt_name = "r2+i2+s_b_s.1+cTEST"

preds = []
for example in examples:
    messages = []

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step. Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    index = random.randint(0, len(train_examples)-1)
    messages.append(SystemMessage(content=f"CONTEXT: Classify the relationship between these table columns: {train_examples[index]}"))
    
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + (StepByStep)INSTRUCTIONS + EXAMPLE CONTEXT  (2)
import random

nr="one"
prompt_name = "r2+i2+s_b_s.1+cTEST2"

preds = []
for example in examples:
    messages = []

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step. Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    index = random.randint(0, len(train_examples)-1)
    messages.append(SystemMessage(content=f"CONTEXT: Classify the relationship between these table columns: {train_examples[index]}, {train_example_labels[index]}"))

    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
with open('GKP-Input/Generated-Tables.pkl', "rb") as f:
    train_tables = pickle.load(f)
with open('GKP-Input/Generated-Table-Labels.pkl', "rb") as f:
    train_labels = pickle.load(f)

# %%
#Role + instructions + steb by step + Generated Knowledge (GKP)
import random

nr="one"
prompt_name = "r2+i2+s_b_s+GKP"

preds = []
for example in examples:
    messages = []

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    
    index_gen = random.randint(0, len(train_tables)-1)
    messages.append(HumanMessage(content=f"This is an example of a table that includes the label '{train_labels[index_gen]}':\n{train_tables[index_gen]}"))
   
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
messages
# Out:
# [SystemMessage(content='You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: recipe cuisine, author, family name, away team, closes, part of series, prep time, gender, honorific suffix, production company, available language, opens, organizer, unit code, recipe instructions, brand, copyright year, cooking method, in album, street address, cook time, best rating, currencies accepted, unit text, director, image, measurements, hiring organization, day of week, publisher, price range, genre, telephone, worst rating, weight, available delivery method, postal code, serves cuisine, book format, nationality, product ID, birth date, birth place, given name, price currency, start date, by artist, nutrition, locality of address, number of tracks, latitude, job title, total time, death date, category, suitable for diet, book edition, text, employment type, opening hours, date created, release date, payment accepted, longitude, valid through, duration, content rating, number of pages, description, event status, home team, price, headline, date published, manufacturer, rating value, amenity feature, alumni of, in language, check-in time, checkout time, url, gtin, color, recipe ingredient, actor, date posted, availability, isbn, event attendance mode, episode number, track, country of origin, address country, recipe category, fax number, review, end date, address, location, model, email, performer, valid from, region of address, item condition, material, serving size.'),
#  SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."),
#  SystemMessage(content="Let's think step by step."),
#  HumanMessage(content='This is an example of a table that includes the label \'description\':\nColumn 1 (Description): Student Name\nColumn 2: Age\nColumn 3: Favorite Color\nColumn 4: Height\n\nValues:\n1. Emily, 19, Purple, 5\'7"\n2. John, 22, Green, 6\'2"\n3. Sarah, 20, Pink, 5\'5"\n4. Michael, 21, Blue, 5\'10"\n5. Rachel, 18, Red, 5\'3"'),
#  HumanMessage(content="Classify the relationship between these table columns: ['Column 1 || Column 2 || Column 3 || \\nVegetable Potsticker || K3628 || K3628||\\nThai Brand Chicken Satay || K2409 || K2409||\\nApple Cinnamon Oatmeal Flan || K4080 || K4080||\\nCashew Chicken Spring Roll || K863 || K863||\\nTandoori Chicken || K2415 || K2415||\\n']"),
#  AIMessage(content='Column 2: model\nColumn 3: product ID'),
#  HumanMessage(content='Classify the relationship between these table columns: [\'Column 1 || Column 2 || Column 3 || Column 4 || \\nSalva El Tigre || 1 || While celebrating his 40th birthday, Félix worries about his associates\\\' loyalty and confronts Pacho. Walt and his team plan retaliatory kidnappings. || Narcos: Mexico||\\nPimemento || 3 || Adrian Pimento shows up unexpectedly to seek Jake and Charles’ help after claiming someone is trying to kill him. The rest of the squad endures a Workplace Conflict seminar. || Brooklyn Nine-Nine||\\nJim Carrey || 95 || \\\\"Kidding\\\\" and \\\\"Sonic the Hedgehog\\\\" star Jim Carrey sits down with Spade to chat about his start in comedy, his extensive acting career and answer questions from the audience. || Lights Out with David Spade||\\nChapter Two: You Can\\\'t Hurry Love || 2 || Josie finds a job to help pay the bills. Jorge has to make a decision about Ginger. Pepper finds herself low on cash. || Katy Keene||\\nWeb Reflection || 30 || As the third season of Tosh.0 wraps up, the block party of the century gets a Video Breakdown and Daniel auditions to host the Oscars. || Tosh.0||\\n\']')]

# %% [markdown]
# FIVE SHOT CPA TABLE

# %%
import random
#Five-shot table + instructions + roles   # NOT M

nr="five"
prompt_name = "r1+i"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between two or more columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}. Notice, you must not classify Column 1!"))
    messages.append(SystemMessage(content="Your instructions are: 1. Look at the input given to you and make a table out of it. 2. Look at the cell values in detail. 3. For each column, select a relationship that best represents the relationship between that column and the first column of the table. 4. Answer with only one selected relationship for each column with the format Column2: relationship. Don't return any relationship for the first column! 5. Answer only with labels from the provided label set!"))
    

    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE
import random

nr="five"
prompt_name = "r3"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to predict the relationship between the first column with the rest of the columns from a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE
import random

nr="five"
prompt_name = "r4"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table, note that you must not annotate Column 1 and must annotate the rest with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS
import random

nr="five"
prompt_name = "r2+i2"

preds = []
for example in examples:
    messages = []
    

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))

    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + StepByStep
import random

nr="five"
prompt_name = "r2+i2+s_b_s"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + StepByStep
import random

nr="five"
prompt_name = "r2+i2+s_b_s.1"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step. Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))

    
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + MOTIVATION
import random

nr="five"
prompt_name = "r2+i2+m"

preds = []
for example in examples:
    messages = []
    
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))
    
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS + StepByStep + MOTIVATION
import random

nr="five"
prompt_name = "r2+i2+s_b_s+m"

preds = []
for example in examples:
    messages = []
     
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))

    
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + StepByStep + MOTIVATION + INSTRUCTIONS 
import random

nr="five"
prompt_name = "r+s_b_s+m+i2"

preds = []
for example in examples:
    messages = []
     
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step. Your answer is very important. Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))

    
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS (motivation) 
import random

nr="five"
prompt_name = "r+i2(m)"

preds = []
for example in examples:
    messages = []
     
    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas. 7. Your answer is very important. Take your time and think well before answering!"))
    
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + CONTEXT 
import random

nr="five"
prompt_name = "r+c1"

preds = []
for example in examples:
    messages = []

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Property Annotation is a sub-task of Table Annotation and refers to predicting the semantic relation between two or more columns. You have the same task, you are required to label the columns of a given table, aiming to identify the correlation of each column with the initial column in the table."))
    
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + (StepByStep)INSTRUCTIONS + CONTEXT
import random

nr="five"
prompt_name = "r2+i2+s_b_s.1+c1"

preds = []
for example in examples:
    messages = []

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Let's think step by step. Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    messages.append(SystemMessage(content=f"CONTEXT: Column Property Annotation is a sub-task of Table Annotation and refers to predicting the semantic relation between two or more columns. You have the same task, you are required to label the columns of a given table, aiming to identify the correlation of each column with the initial column in the table."))
     
    
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#ROLE + INSTRUCTIONS(MOTIVATION) + CONTEXT + EXAMPLE
import random

nr="five"
prompt_name = "r+i2(m)+c.example"

preds = []
for example in examples:
    messages = []

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas. 7. Your answer is very important. Take your time and think well before answering!"))
    messages.append(SystemMessage(content=f"CONTEXT: Column Property Annotation is a sub-task of Table Annotation and refers to predicting the semantic relation between two or more columns. You have the same task, here is an example how you could solve a CPA task: 'Classify the relationship between these table columns: Columm1: Dog, Cat, Dog.  Column2: lis, moli, brauni. '"
                                  "First we check Columm1: Dog, Cat, Dog."   
                                  "Now we check Column2: lis, moli, brauni. Analyze Column 2 in relation to Column 1. Predict the relation between Column 2 and Column 1"
                                  "Answer: Column 2: pet names"))
     

    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)
# Out:
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600).

# %%
#Role + instructions + steb by step + Generated Knowledge (GKP)
import random

nr="five"
prompt_name = "r2+i2+s_b_s+GKP"

preds = []
for example in examples:
    messages = []

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    messages.append(SystemMessage(content="Let's think step by step."))

    for i in range(0,5):
        index_gen = random.randint(0, len(train_tables)-1)
        messages.append(HumanMessage(content=f"This is an example of a table that includes the label '{train_labels[index_gen]}':\n{train_tables[index_gen]}"))
      
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
#Role + instructions + steb by step + Generated Knowledge (GKP)
import random

nr="five"
prompt_name = "r2+i2+m+GKP"

preds = []
for example in examples:
    messages = []

    messages.append(SystemMessage(content=f"You are a great Table Annotation Specialist and your task is to classify the relationship between the first column and the rest of the columns of a given table with ONLY ONE of the following labels that are separated with comma: {labels_joined}."))
    messages.append(SystemMessage(content="Your instructions are: 1.Review the provided input and organize it into a table format. 2.Carefully examine the values within each cell of the table. 3.For every column in the table, choose a single label that best represents the relationship between that column and the first column of the table. 4. Note, you must not annotate Column 1!. 5.Answer with your selected label for each column, following the format: 'Column2: SelectedLabel, Column3: SelectedLabel, ...'. 6. Ensure that you use ONLY ONE label from the provided label set for each column, and separate your responses with commas."))
    messages.append(SystemMessage(content="Your answer is very important. Take your time and think well before answering!"))

    for i in range(0,5):
        index_gen = random.randint(0, len(train_tables)-1)
        messages.append(HumanMessage(content=f"This is an example of a table that includes the label '{train_labels[index_gen]}':\n{train_tables[index_gen]}"))
      
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_example_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify the relationship between these table columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %% [markdown]
# Save predictions

# %%
preds
# Out:
# ['Column 2: description, Column 3: availability, Column 4: price',
#  'Column 2: event status\nColumn 3: event status',
#  'Column 2: event title,\nColumn 3: organizer,\nColumn 4: email',
#  'Column 2: telephone\nColumn 3: country of origin\nColumn 4: postal code',
#  'Column 2: genre\nColumn 3: performer\nColumn 4: image',
#  'Column 2: in language, Column 3: content rating, Column 4: genre, Column 5: performer',
#  'Column 2: nationality, Column 3: job title',
#  'Column 2: birth date\nColumn 3: gender\nColumn 4: job title',
#  'Column 2: job title\nColumn 3: telephone\nColumn 4: gender',
#  'Column 2: description, Column 3: in language, Column 4: item condition',
#  'Column 2: author\nColumn 3: price currency\nColumn 4: publisher\nColumn 5: availability\nColumn 6: price',
#  'Column 2: performer\nColumn 3: performer\nColumn 4: description',
#  'Column 2: start date\nColumn 3: address\nColumn 4: event attendance mode\nColumn 5: end date\nColumn 6: event status',
#  'Column 2: address\nColumn 3: address\nColumn 4: address\nColumn 5: address\nColumn 6: address\nColumn 7: address\nColumn 8: address\nColumn 9: locality of address',
#  'Column 2: check-in time\nColumn 3: available language\nColumn 4: price range',
#  'Column 2: address\nColumn 3: opening hours\nColumn 4: image\nColumn 5: email',
#  'Column 2: opening hours\nColumn 3: best rating\nColumn 4: worst rating\nColumn 5: review\nColumn 6: price currency',
#  'Column 2: duration\nColumn 3: content rating\nColumn 4: production company',
#  'Column 2: director\nColumn 3: duration\nColumn 4: release date\nColumn 5: content rating\nColumn 6: performer\nColumn 7: rating value\nColumn 8: number of tracks\nColumn 9: total time',
#  'Column 2: description\nColumn 3: performer\nColumn 4: brand',
#  'Column 2: in album\nColumn 3: number of tracks\nColumn 4: total time\nColumn 5: by artist\nColumn 6: image',
#  'Column 2: text, Column 3: gender',
#  'Column 2: job title\nColumn 3: alumni of\nColumn 4: degree',
#  'Column 2: product ID\nColumn 3: color\nColumn 4: height\nColumn 5: width\nColumn 6: weight',
#  'Column 2: manufacturer\nColumn 3: date published',
#  'Column 2: recipe instructions\nColumn 3: recipe cuisine\nColumn 4: cooking method',
#  'Column 2: cooking method, Column 3: duration',
#  'Column 2: description, Column 3: recipe instructions, Column 4: rating value, Column 5: prep time, Column 6: cook time, Column 7: suitable for diet',
#  'Column 2: start date\nColumn 3: end date\nColumn 4: organizer\nColumn 5: url',
#  'Column 2: valid through\nColumn 3: location\nColumn 4: start date',
#  'Column 2: start date, Column 3: event attendance mode, Column 4: event status',
#  'Column 2: start date, Column 3: event status, Column 4: organizer, Column 5: email',
#  'Column 2: price\nColumn 3: address country\nColumn 4: country of origin\nColumn 5: locality of address\nColumn 6: street address',
#  'Column 2: telephone\nColumn 3: telephone\nColumn 4: postal code\nColumn 5: street address\nColumn 6: price currency',
#  'Column 2: telephone, Column 3: telephone, Column 4: street address, Column 5: address country, Column 6: locality of address, Column 7: postal code',
#  'Column 2: telephone\nColumn 3: fax number\nColumn 4: locality of address\nColumn 5: locality of address\nColumn 6: country of origin',
#  'Column 2: release date, Column 3: duration, Column 4: director, Column 5: actor',
#  'Column 2: release date\nColumn 3: performer\nColumn 4: director',
#  'Column 2: date published\nColumn 3: item condition\nColumn 4: category',
#  'Column 2: release date, Column 3: brand',
#  'Column 2: product ID',
#  'Column 2: release date\nColumn 3: description',
#  'Column 2: start date\nColumn 3: end date\nColumn 4: organizer\nColumn 5: performer',
#  'Column 2: valid from, Column 3: valid through, Column 4: publisher, Column 5: brand, Column 6: in language, Column 7: event status, Column 8: event attendance mode',
#  'Column 2: telephone\nColumn 3: address\nColumn 4: opening hours\nColumn 5: latitude\nColumn 6: longitude\nColumn 7: end date\nColumn 8: start date',
#  'Column 2: telephone, Column 3: telephone, Column 4: price range, Column 5: url, Column 6: payment accepted, Column 7: price currency, Column 8: postal code, Column 9: country of origin, Column 10: locality of address, Column 11: street address, Column 12: description, Column 13: rating value, Column 14: best rating, Column 15: worst rating, Column 16: latitude',
#  'Column 2: telephone,\nColumn 3: country of origin,\nColumn 4: day of week,\nColumn 5: check-in time,\nColumn 6: check-out time,\nColumn 7: region of address',
#  'Column 2: duration, Column 3: release date, Column 4: content rating, Column 5: director, Column 6: best rating, Column 7: number of tracks, Column 8: total time, Column 9: performer',
#  'Column 2: release date, Column 3: in language, Column 4: by artist, Column 5: image, Column 6: url, Column 7: publisher, Column 8: best rating, Column 9: worst rating',
#  'Column 2: date published\nColumn 3: end date\nColumn 4: given name\nColumn 5: family name\nColumn 6: gender',
#  'Column 2: birth date\nColumn 3: death date\nColumn 4: description',
#  'Column 2: measurements\nColumn 3: nationality\nColumn 4: birth date\nColumn 5: birth place',
#  'Column 2: weight\nColumn 3: date created',
#  'Column 2: recipe name,\nColumn 3: serving size,\nColumn 4: weight,\nColumn 5: prep time,\nColumn 6: cook time,\nColumn 7: total time,\nColumn 8: recipe ingredients,\nColumn 9: recipe category,\nColumn 10: recipe cuisine,\nColumn 11: recipe instructions,\nColumn 12: duration,\nColumn 13: event status,\nColumn 14: suitable for diet,\nColumn 15: cuisine,\nColumn 16: nutrition,\nColumn 17: event attendance mode,\nColumn 18: amenity feature',
#  'Column 2: book title\nColumn 3: number of pages\nColumn 4: rating value',
#  'Column 2: category',
#  'Column 2: description',
#  'Column 2: locality of address, Column 3: street address',
#  'Column 2: isbn, Column 3: publisher',
#  'Column 2: price\nColumn 3: price currency\nColumn 4: author\nColumn 5: availability',
#  'Column 2: price currency, Column 3: author, Column 4: availability, Column 5: price',
#  'Column 2: release date,\nColumn 3: price currency,\nColumn 4: item condition,\nColumn 5: price,\nColumn 6: availability',
#  'Column 2: language\nColumn 3: publisher\nColumn 4: isbn\nColumn 5: book format\nColumn 6: author\nColumn 7: number of pages\nColumn 8: category',
#  'Column 2: release date, Column 3: author, Column 4: publisher, Column 5: isbn, Column 6: url, Column 7: category',
#  'Column 2: release date, Column 3: description, Column 4: isbn, Column 5: author, Column 6: url, Column 7: category',
#  'Column 2: job title, Column 3: image, Column 4: description, Column 5: email',
#  'Column 2: postal code\nColumn 3: gender\nColumn 4: region of address',
#  'Column 2: number of pages\nColumn 3: publisher\nColumn 4: url\nColumn 5: author\nColumn 6: gtin',
#  'Column 2: isbn\nColumn 3: date published\nColumn 4: number of pages',
#  'Column 2: price currency, Column 3: book edition, Column 4: availability, Column 5: price, Column 6: author',
#  'Column 2: brand\nColumn 3: performer\nColumn 4: description\nColumn 5: date published',
#  'Column 2: locality of address\nColumn 3: price range\nColumn 4: country of origin',
#  'Column 2: fax number\nColumn 3: description\nColumn 4: payment accepted\nColumn 5: best rating\nColumn 6: best rating',
#  'Column 2: release date\nColumn 3: director\nColumn 4: actor',
#  'Column 2: release date\nColumn 3: director\nColumn 4: duration\nColumn 5: performer',
#  'Column 2: director, Column 3: country of origin',
#  'Column 2: nationality\nColumn 3: gender\nColumn 4: birth date',
#  'Column 2: job title\nColumn 3: birth date\nColumn 4: nationality',
#  'Column 2: job title\nColumn 3: given name\nColumn 4: family name',
#  'Column 2: family name\nColumn 3: given name\nColumn 4: death date\nColumn 5: locality of address\nColumn 6: birth date',
#  'Column 2: brand, Column 3: manufacturer, Column 4: unit text',
#  'Column 2: color\nColumn 3: item condition\nColumn 4: material\nColumn 5: brand',
#  'Column 2: recipe cuisine\nColumn 3: recipe ingredient\nColumn 4: cook time\nColumn 5: recipe category\nColumn 6: prep time\nColumn 7: recipe instructions\nColumn 8: suitable for diet',
#  'Column 2: cook time\nColumn 3: recipe ingredient\nColumn 4: recipe category\nColumn 5: cook time\nColumn 6: serves cuisine\nColumn 7: recipe instructions',
#  'Column 2: in language, Column 3: isbn, Column 4: number of pages, Column 5: available language',
#  'Column 2: publisher, Column 3: isbn, Column 4: author, Column 5: book format, Column 6: number of pages, Column 7: available language',
#  'Column 2: isbn\nColumn 3: item condition\nColumn 4: available delivery method',
#  'Column 2: start date, Column 3: description, Column 4: availability, Column 5: price currency, Column 6: date posted, Column 7: organizer',
#  'Column 2: start date\nColumn 3: address\nColumn 4: end date',
#  'Column 2: start date, Column 3: performer, Column 4: end date',
#  'Column 2: start date, Column 3: in language, Column 4: rating value, Column 5: end date',
#  'Column 2: url, Column 3: venue, Column 4: image',
#  'Column 2: content rating\nColumn 3: release date',
#  'Column 2: start date, Column 3: end date, Column 4: performer, Column 5: locality of address, Column 6: venue',
#  'Column 2: date published\nColumn 3: job title\nColumn 4: url\nColumn 5: hiring organization',
#  'Column 2: start date, Column 3: job title, Column 4: hiring organization, Column 5: employment type',
#  'Column 2: start date,\nColumn 3: job title,\nColumn 4: employment type,\nColumn 5: hiring organization',
#  'Column 2: telephone, Column 3: email, Column 4: locality of address, Column 5: street address, Column 6: postal code, Column 7: longitude, Column 8: latitude, Column 9: day of week, Column 10: check-in time, Column 11: address country',
#  'Column 2: production company, Column 3: genre, Column 4: rating value, Column 5: performer',
#  'Column 2: country of origin, Column 3: director',
#  'Column 2: number of tracks, Column 3: performer, Column 4: url, Column 5: total time, Column 6: track',
#  'Column 2: duration\nColumn 3: in album\nColumn 4: by artist',
#  'Column 2: duration\nColumn 3: in album\nColumn 4: by artist',
#  'Column 2: duration\nColumn 3: album\nColumn 4: by artist',
#  'Column 2: duration\nColumn 3: genre\nColumn 4: by artist\nColumn 5: manufacturer',
#  'Column 2: honorific suffix, Column 3: given name, Column 4: family name',
#  'Column 2: alumni of\nColumn 3: gender',
#  'Column 2: product ID\nColumn 3: gtin\nColumn 4: color\nColumn 5: item condition\nColumn 6: item condition\nColumn 7: item condition\nColumn 8: rating value\nColumn 9: rating value\nColumn 10: rating value\nColumn 11: category\nColumn 12: brand',
#  'Column 2: model\nColumn 3: color\nColumn 4: item condition',
#  'Column 2: item condition\nColumn 3: gtin\nColumn 4: price\nColumn 5: manufacturer\nColumn 6: release date',
#  'Column 2: available delivery method, Column 3: product ID, Column 4: category',
#  'Column 2: gtin\nColumn 3: brand\nColumn 4: product ID',
#  'Column 2: product ID\nColumn 3: available delivery method',
#  'Column 2: material, Column 3: weight, Column 4: product ID',
#  'Column 2: material\nColumn 3: manufacturer',
#  'Column 2: unit code\nColumn 3: gtin',
#  'Column 2: cooking method, Column 3: serving size',
#  'Column 2: suitable for diet\nColumn 3: nationality\nColumn 4: serving size',
#  'Column 2: opening hours, Column 3: payment accepted, Column 4: serves cuisine',
#  'Column 2: opening hours\nColumn 3: payment accepted\nColumn 4: serves cuisine',
#  'Column 2: home team\nColumn 3: away team\nColumn 4: start date',
#  'Column 2: start date\nColumn 3: away team\nColumn 4: home team',
#  'Column 2: episode number\nColumn 3: description\nColumn 4: part of series',
#  'Column 2: url\nColumn 3: part of series',
#  'Column 2: number of tracks, Column 3: description, Column 4: in language']

# %%
file_name=f'Predictions/{model_name}/table/{nr}-shot/chat-table-{prompt_name}-{nr}-shot.pkl'
f = open(file_name,'wb')
pickle.dump(preds,f)
f.close()

# %% [markdown]
# ## Evaluation

# %%
predictions = []
i=0
for j, table_preds in enumerate(preds):
   
    table_number = len(test[j][2])
    
    if "Class:" in table_preds:
        table_preds = table_preds.split("Class:")[1]
      

    if ":" in table_preds or "-" in table_preds:
        if ":" in table_preds:
            separator = ":"
            start = 1
            end = table_number+1
        else:
            separator = "-"  
            start = 1
            end = table_number+1
    else:
        separator = ","
        start = 0
        end = table_number
        
    col_preds = table_preds.split(separator)[start:end]
    
    for pred in col_preds:
        i+=1
     
        if "\n" in pred:
            pred = pred.split('\n')[0].strip()
        if "," in pred:
            pred = pred.split(",")[0].strip()
   
        if '(' in pred:
            pred = pred.split("(")[0].strip()
       
        if '.' in pred:
            pred = pred.split(".")[0].strip()
        pred = pred.strip().lower()
        
        if pred in text_to_label:
            predictions.append(text_to_label[pred])
        else:
            print(f"For test example {i} out of label space prediction: {pred}")
            predictions.append('-')
  
    if len(col_preds) < table_number:
        for m in range(0, table_number-len(col_preds)):
            predictions.append('-')
            i+=1
# Out:
# For test example 6 out of label space prediction: event title
# For test example 87 out of label space prediction: degree
# For test example 88 out of label space prediction: product id
# For test example 90 out of label space prediction: height
# For test example 91 out of label space prediction: width
# For test example 153 out of label space prediction: product id
# For test example 195 out of label space prediction: check-out time
# For test example 227 out of label space prediction: recipe name
# For test example 233 out of label space prediction: recipe ingredients
# For test example 240 out of label space prediction: cuisine
# For test example 244 out of label space prediction: book title
# For test example 266 out of label space prediction: language
# For test example 390 out of label space prediction: venue
# For test example 398 out of label space prediction: venue
# For test example 440 out of label space prediction: album
# For test example 451 out of label space prediction: product id
# For test example 471 out of label space prediction: product id
# For test example 475 out of label space prediction: product id
# For test example 476 out of label space prediction: product id
# For test example 480 out of label space prediction: product id

# %%
predictions
# Out:
# ['description',
#  'availability',
#  'priceRange',
#  'eventStatus',
#  'eventStatus',
#  '-',
#  'organizer',
#  'email',
#  'telephone',
#  'countryOfOrigin',
#  'postalCode',
#  'genre',
#  'performer',
#  'image',
#  'inLanguage',
#  'contentRating',
#  'genre',
#  'performer',
#  'nationality',
#  'jobTitle',
#  'birthDate',
#  'gender',
#  'jobTitle',
#  'jobTitle',
#  'telephone',
#  'gender',
#  'description',
#  'inLanguage',
#  'itemCondition',
#  'author',
#  'priceCurrency',
#  'publisher',
#  'availability',
#  'priceRange',
#  'performer',
#  'performer',
#  'description',
#  'startDate',
#  'address',
#  'eventAttendanceMode',
#  'endDate',
#  'eventStatus',
#  'address',
#  'address',
#  'address',
#  'address',
#  'address',
#  'address',
#  'address',
#  'addressLocality',
#  'checkInTime',
#  'availableLanguage',
#  'priceRange',
#  'address',
#  'openingHours',
#  'image',
#  'email',
#  'openingHours',
#  'bestRating',
#  'worstRating',
#  'review',
#  'priceCurrency',
#  '-',
#  'duration',
#  'contentRating',
#  'productionCompany',
#  'director',
#  'duration',
#  'releaseDate',
#  'contentRating',
#  'performer',
#  'ratingValue',
#  'numTracks',
#  'totalTime',
#  'description',
#  'performer',
#  'brand',
#  'inAlbum',
#  'numTracks',
#  'totalTime',
#  'byArtist',
#  'image',
#  'text',
#  'gender',
#  'jobTitle',
#  'alumniOf',
#  '-',
#  '-',
#  'color',
#  '-',
#  '-',
#  'weight',
#  'manufacturer',
#  'datePublished',
#  'recipeInstructions',
#  'recipeCuisine',
#  'cookingMethod',
#  'cookingMethod',
#  'duration',
#  'description',
#  'recipeInstructions',
#  'ratingValue',
#  'prepTime',
#  'cookTime',
#  'suitableForDiet',
#  'startDate',
#  'endDate',
#  'organizer',
#  'url',
#  'validThrough',
#  'location',
#  'startDate',
#  'startDate',
#  'eventAttendanceMode',
#  'eventStatus',
#  'startDate',
#  'eventStatus',
#  'organizer',
#  'email',
#  'priceRange',
#  'addressCountry',
#  'countryOfOrigin',
#  'addressLocality',
#  'streetAddress',
#  'telephone',
#  'telephone',
#  'postalCode',
#  'streetAddress',
#  'priceCurrency',
#  'telephone',
#  'telephone',
#  'streetAddress',
#  'addressCountry',
#  'addressLocality',
#  'postalCode',
#  'telephone',
#  'faxNumber',
#  'addressLocality',
#  'addressLocality',
#  'countryOfOrigin',
#  'releaseDate',
#  'duration',
#  'director',
#  'actor',
#  'releaseDate',
#  'performer',
#  'director',
#  'datePublished',
#  'itemCondition',
#  'category',
#  'releaseDate',
#  'brand',
#  '-',
#  'releaseDate',
#  'description',
#  'startDate',
#  'endDate',
#  'organizer',
#  'performer',
#  'validFrom',
#  'validThrough',
#  'publisher',
#  'brand',
#  'inLanguage',
#  'eventStatus',
#  'eventAttendanceMode',
#  'telephone',
#  'address',
#  'openingHours',
#  'latitude',
#  'longitude',
#  'endDate',
#  'startDate',
#  'telephone',
#  'telephone',
#  'priceRange',
#  'url',
#  'paymentAccepted',
#  'priceCurrency',
#  'postalCode',
#  'countryOfOrigin',
#  'addressLocality',
#  'streetAddress',
#  'description',
#  'ratingValue',
#  'bestRating',
#  'worstRating',
#  'latitude',
#  '-',
#  '-',
#  'telephone',
#  'countryOfOrigin',
#  'dayOfWeek',
#  'checkInTime',
#  '-',
#  'addressRegion',
#  'duration',
#  'releaseDate',
#  'contentRating',
#  'director',
#  'bestRating',
#  'numTracks',
#  'totalTime',
#  'performer',
#  'releaseDate',
#  'inLanguage',
#  'byArtist',
#  'image',
#  'url',
#  'publisher',
#  'bestRating',
#  'worstRating',
#  'datePublished',
#  'endDate',
#  'givenName',
#  'familyName',
#  'gender',
#  'birthDate',
#  'deathDate',
#  'description',
#  'measurements',
#  'nationality',
#  'birthDate',
#  'birthPlace',
#  'weight',
#  'dateCreated',
#  '-',
#  'servingSize',
#  'weight',
#  'prepTime',
#  'cookTime',
#  'totalTime',
#  '-',
#  'recipeCategory',
#  'recipeCuisine',
#  'recipeInstructions',
#  'duration',
#  'eventStatus',
#  'suitableForDiet',
#  '-',
#  'nutrition',
#  'eventAttendanceMode',
#  'amenityFeature',
#  '-',
#  'numberOfPages',
#  'ratingValue',
#  'category',
#  'description',
#  'addressLocality',
#  'streetAddress',
#  'isbn',
#  'publisher',
#  'priceRange',
#  'priceCurrency',
#  'author',
#  'availability',
#  'priceCurrency',
#  'author',
#  'availability',
#  'priceRange',
#  'releaseDate',
#  'priceCurrency',
#  'itemCondition',
#  'priceRange',
#  'availability',
#  '-',
#  'publisher',
#  'isbn',
#  'bookFormat',
#  'author',
#  'numberOfPages',
#  'category',
#  'releaseDate',
#  'author',
#  'publisher',
#  'isbn',
#  'url',
#  'category',
#  'releaseDate',
#  'description',
#  'isbn',
#  'author',
#  'url',
#  'category',
#  'jobTitle',
#  'image',
#  'description',
#  'email',
#  'postalCode',
#  'gender',
#  'addressRegion',
#  'numberOfPages',
#  'publisher',
#  'url',
#  'author',
#  'gtin',
#  'isbn',
#  'datePublished',
#  'numberOfPages',
#  'priceCurrency',
#  'bookEdition',
#  'availability',
#  'priceRange',
#  'author',
#  'brand',
#  'performer',
#  'description',
#  'datePublished',
#  'addressLocality',
#  'priceRange',
#  'countryOfOrigin',
#  'faxNumber',
#  'description',
#  'paymentAccepted',
#  'bestRating',
#  'bestRating',
#  'releaseDate',
#  'director',
#  'actor',
#  'releaseDate',
#  'director',
#  'duration',
#  'performer',
#  'director',
#  'countryOfOrigin',
#  'nationality',
#  'gender',
#  'birthDate',
#  'jobTitle',
#  'birthDate',
#  'nationality',
#  'jobTitle',
#  'givenName',
#  'familyName',
#  'familyName',
#  'givenName',
#  'deathDate',
#  'addressLocality',
#  'birthDate',
#  'brand',
#  'manufacturer',
#  'unitText',
#  'color',
#  'itemCondition',
#  'material',
#  'brand',
#  'recipeCuisine',
#  'recipeIngredient',
#  'cookTime',
#  'recipeCategory',
#  'prepTime',
#  'recipeInstructions',
#  'suitableForDiet',
#  'cookTime',
#  'recipeIngredient',
#  'recipeCategory',
#  'cookTime',
#  'servesCuisine',
#  'recipeInstructions',
#  'inLanguage',
#  'isbn',
#  'numberOfPages',
#  'availableLanguage',
#  'publisher',
#  'isbn',
#  'author',
#  'bookFormat',
#  'numberOfPages',
#  'availableLanguage',
#  'isbn',
#  'itemCondition',
#  'availableDeliveryMethod',
#  'startDate',
#  'description',
#  'availability',
#  'priceCurrency',
#  'datePosted',
#  'organizer',
#  'startDate',
#  'address',
#  'endDate',
#  'startDate',
#  'performer',
#  'endDate',
#  'startDate',
#  'inLanguage',
#  'ratingValue',
#  'endDate',
#  'url',
#  '-',
#  'image',
#  'contentRating',
#  'releaseDate',
#  'startDate',
#  'endDate',
#  'performer',
#  'addressLocality',
#  '-',
#  'datePublished',
#  'jobTitle',
#  'url',
#  'hiringOrganization',
#  'startDate',
#  'jobTitle',
#  'hiringOrganization',
#  'employmentType',
#  'startDate',
#  'jobTitle',
#  'employmentType',
#  'hiringOrganization',
#  'telephone',
#  'email',
#  'addressLocality',
#  'streetAddress',
#  'postalCode',
#  'longitude',
#  'latitude',
#  'dayOfWeek',
#  'checkInTime',
#  'addressCountry',
#  '-',
#  'productionCompany',
#  'genre',
#  'ratingValue',
#  'performer',
#  'countryOfOrigin',
#  'director',
#  'numTracks',
#  'performer',
#  'url',
#  'totalTime',
#  'track',
#  'duration',
#  'inAlbum',
#  'byArtist',
#  'duration',
#  'inAlbum',
#  'byArtist',
#  'duration',
#  '-',
#  'byArtist',
#  'duration',
#  'genre',
#  'byArtist',
#  'manufacturer',
#  'honorificSuffix',
#  'givenName',
#  'familyName',
#  'alumniOf',
#  'gender',
#  '-',
#  'gtin',
#  'color',
#  'itemCondition',
#  'itemCondition',
#  'itemCondition',
#  'ratingValue',
#  'ratingValue',
#  'ratingValue',
#  'category',
#  'brand',
#  'model',
#  'color',
#  'itemCondition',
#  'itemCondition',
#  'gtin',
#  'priceRange',
#  'manufacturer',
#  'releaseDate',
#  'availableDeliveryMethod',
#  '-',
#  'category',
#  'gtin',
#  'brand',
#  '-',
#  '-',
#  'availableDeliveryMethod',
#  'material',
#  'weight',
#  '-',
#  'material',
#  'manufacturer',
#  'unitCode',
#  'gtin',
#  'cookingMethod',
#  'servingSize',
#  'suitableForDiet',
#  'nationality',
#  'servingSize',
#  'openingHours',
#  'paymentAccepted',
#  'servesCuisine',
#  'openingHours',
#  'paymentAccepted',
#  'servesCuisine',
#  'homeTeam',
#  'awayTeam',
#  'startDate',
#  'startDate',
#  'awayTeam',
#  'homeTeam',
#  'episodeNumber',
#  'description',
#  'partOfSeries',
#  'url',
#  'partOfSeries',
#  'numTracks',
#  'description',
#  'inLanguage']

# %% [markdown]
# ### Calculate Precision, Recall, Macro-F1 and Micro-F1

# %%
def calculate_f1_scores(y_tests, y_preds, num_classes, types):

    y_tests = [types.index(y) for y in y_tests]
    y_preds = [types.index(y) for y in y_preds]
    
    
    cm = np.zeros(shape=(num_classes,num_classes))
    
    for i in range(len(y_tests)):
        cm[y_preds[i]][y_tests[i]] += 1
        
    report = {}
    
    for j in range(len(cm[0])):
        report[j] = {}
        report[j]['FN'] = 0
        report[j]['FP'] = 0
        report[j]['TP'] = cm[j][j]

        for i in range(len(cm)):
            if i != j:
                report[j]['FN'] += cm[i][j]
        for k in range(len(cm[0])):
            if k != j:
                report[j]['FP'] += cm[j][k]

        precision = report[j]['TP'] / (report[j]['TP'] + report[j]['FP'])
        recall = report[j]['TP'] / (report[j]['TP'] + report[j]['FN'])
        f1 = 2*precision*recall / (precision + recall)
        
        if np.isnan(f1):
            f1 = 0
        if np.isnan(precision):
            f1 = 0
        if np.isnan(recall):
            f1 = 0

        report[j]['p'] =  precision
        report[j]['r'] =  recall
        report[j]['f1'] = f1
    
    all_fn = 0
    all_tp = 0
    all_fp = 0

    for r in report:
        if r != num_classes-1:
            all_fn += report[r]['FN']
            all_tp += report[r]['TP']
            all_fp += report[r]['FP']
        
    class_f1s = [ report[class_]['f1'] for class_ in report]
    class_p = [ 0 if np.isnan(report[class_]['p']) else report[class_]['p'] for class_ in report]
    class_r = [ 0 if np.isnan(report[class_]['r']) else report[class_]['r'] for class_ in report]
    macro_f1 = sum(class_f1s[:-1]) / (num_classes-1)
    
    p =  sum(class_p[:-1]) / (num_classes-1)
    r =  sum(class_r[:-1]) / (num_classes-1)
    micro_f1 = all_tp / ( all_tp + (1/2 * (all_fp + all_fn) )) 
    
    per_class_eval = {}
    for index, t in enumerate(types[:-1]):
        per_class_eval[t] = {"Precision":class_p[index], "Recall": class_r[index], "F1": class_f1s[index]}
    
    evaluation = {
        "Micro-F1": micro_f1,
        "Macro-F1": macro_f1,
        "Precision": p,
        "Recall": r
    }
    
    return [ evaluation, per_class_eval]

# %%
types = list(set(labels))
types = types + ["-"] if "-" in predictions else types
evaluation, per_class_eval = calculate_f1_scores(labels, predictions, len(types), types)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_17752\425719141.py:27: RuntimeWarning: invalid value encountered in scalar divide
#   precision = report[j]['TP'] / (report[j]['TP'] + report[j]['FP'])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_17752\425719141.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   f1 = 2*precision*recall / (precision + recall)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_17752\425719141.py:28: RuntimeWarning: invalid value encountered in scalar divide
#   recall = report[j]['TP'] / (report[j]['TP'] + report[j]['FN'])

# %%
evaluation
# Out:
# {'Micro-F1': 0.5915492957746479,
#  'Macro-F1': 0.5376724149062467,
#  'Precision': 0.5748111071027736,
#  'Recall': 0.561792528459195}

# %%
per_class_eval
# Out:
# {'gender': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'currenciesAccepted': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'bestRating': {'Precision': 0.3333333333333333,
#   'Recall': 0.2222222222222222,
#   'F1': 0.26666666666666666},
#  'awayTeam': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'measurements': {'Precision': 1.0, 'Recall': 0.14285714285714285, 'F1': 0.25},
#  'episodeNumber': {'Precision': 1.0, 'Recall': 0.5, 'F1': 0.6666666666666666},
#  'telephone': {'Precision': 0.6666666666666666,
#   'Recall': 0.8888888888888888,
#   'F1': 0.761904761904762},
#  'alumniOf': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'addressRegion': {'Precision': 0.5, 'Recall': 0.2, 'F1': 0.28571428571428575},
#  'postalCode': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'recipeInstructions': {'Precision': 0.6,
#   'Recall': 0.75,
#   'F1': 0.6666666666666665},
#  'recipeCuisine': {'Precision': 0.3333333333333333,
#   'Recall': 0.25,
#   'F1': 0.28571428571428575},
#  'color': {'Precision': 0.75, 'Recall': 0.75, 'F1': 0.75},
#  'recipeCategory': {'Precision': 0.6666666666666666,
#   'Recall': 0.5,
#   'F1': 0.5714285714285715},
#  'cookingMethod': {'Precision': 0.6666666666666666,
#   'Recall': 0.6666666666666666,
#   'F1': 0.6666666666666666},
#  'availableLanguage': {'Precision': 0.3333333333333333,
#   'Recall': 1.0,
#   'F1': 0.5},
#  'review': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'performer': {'Precision': 0.06666666666666667,
#   'Recall': 0.5,
#   'F1': 0.11764705882352941},
#  'productID': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'inLanguage': {'Precision': 0.2857142857142857,
#   'Recall': 0.4,
#   'F1': 0.3333333333333333},
#  'description': {'Precision': 0.6875,
#   'Recall': 0.9166666666666666,
#   'F1': 0.7857142857142857},
#  'deathDate': {'Precision': 1.0, 'Recall': 0.6666666666666666, 'F1': 0.8},
#  'isbn': {'Precision': 0.875,
#   'Recall': 0.7777777777777778,
#   'F1': 0.823529411764706},
#  'longitude': {'Precision': 0.5, 'Recall': 0.25, 'F1': 0.3333333333333333},
#  'text': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'weight': {'Precision': 0.75, 'Recall': 0.75, 'F1': 0.75},
#  'contentRating': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'opens': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'endDate': {'Precision': 0.5555555555555556,
#   'Recall': 0.7142857142857143,
#   'F1': 0.6250000000000001},
#  'headline': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'brand': {'Precision': 0.375, 'Recall': 1.0, 'F1': 0.5454545454545454},
#  'partOfSeries': {'Precision': 1.0, 'Recall': 0.6666666666666666, 'F1': 0.8},
#  'familyName': {'Precision': 1.0, 'Recall': 0.8, 'F1': 0.888888888888889},
#  'latitude': {'Precision': 0.6666666666666666,
#   'Recall': 0.5,
#   'F1': 0.5714285714285715},
#  'suitableForDiet': {'Precision': 0.5,
#   'Recall': 1.0,
#   'F1': 0.6666666666666666},
#  'bookEdition': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'author': {'Precision': 1.0, 'Recall': 0.75, 'F1': 0.8571428571428571},
#  'ratingValue': {'Precision': 0.1111111111111111,
#   'Recall': 0.14285714285714285,
#   'F1': 0.125},
#  'numTracks': {'Precision': 0.4, 'Recall': 1.0, 'F1': 0.5714285714285715},
#  'totalTime': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'closes': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'organizer': {'Precision': 0.4,
#   'Recall': 0.2857142857142857,
#   'F1': 0.3333333333333333},
#  'validThrough': {'Precision': 0.5, 'Recall': 0.5, 'F1': 0.5},
#  'publisher': {'Precision': 0.75,
#   'Recall': 0.8571428571428571,
#   'F1': 0.7999999999999999},
#  'priceRange': {'Precision': 0.36363636363636365,
#   'Recall': 0.8,
#   'F1': 0.5000000000000001},
#  'availability': {'Precision': 1.0, 'Recall': 0.875, 'F1': 0.9333333333333333},
#  'employmentType': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'inAlbum': {'Precision': 0.3333333333333333,
#   'Recall': 0.25,
#   'F1': 0.28571428571428575},
#  'genre': {'Precision': 0.75, 'Recall': 0.5, 'F1': 0.6},
#  'recipeIngredient': {'Precision': 1.0,
#   'Recall': 0.6666666666666666,
#   'F1': 0.8},
#  'eventStatus': {'Precision': 0.5714285714285714,
#   'Recall': 0.8,
#   'F1': 0.6666666666666666},
#  'itemCondition': {'Precision': 0.6, 'Recall': 1.0, 'F1': 0.7499999999999999},
#  'image': {'Precision': 0.8333333333333334,
#   'Recall': 0.7142857142857143,
#   'F1': 0.7692307692307692},
#  'countryOfOrigin': {'Precision': 0.25, 'Recall': 1.0, 'F1': 0.4},
#  'amenityFeature': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'priceCurrency': {'Precision': 0.6666666666666666, 'Recall': 1.0, 'F1': 0.8},
#  'honorificSuffix': {'Precision': 1.0,
#   'Recall': 0.5,
#   'F1': 0.6666666666666666},
#  'dayOfWeek': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'unitCode': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'releaseDate': {'Precision': 0.21428571428571427, 'Recall': 0.5, 'F1': 0.3},
#  'worstRating': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'jobTitle': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'datePublished': {'Precision': 0.16666666666666666,
#   'Recall': 0.1111111111111111,
#   'F1': 0.13333333333333333},
#  'byArtist': {'Precision': 0.5, 'Recall': 0.5, 'F1': 0.5},
#  'manufacturer': {'Precision': 0.4, 'Recall': 0.6666666666666666, 'F1': 0.5},
#  'director': {'Precision': 0.875,
#   'Recall': 0.6363636363636364,
#   'F1': 0.7368421052631579},
#  'openingHours': {'Precision': 0.8, 'Recall': 1.0, 'F1': 0.888888888888889},
#  'productionCompany': {'Precision': 1.0,
#   'Recall': 0.5,
#   'F1': 0.6666666666666666},
#  'unitText': {'Precision': 1.0, 'Recall': 0.5, 'F1': 0.6666666666666666},
#  'url': {'Precision': 0.8, 'Recall': 1.0, 'F1': 0.888888888888889},
#  'cookTime': {'Precision': 0.4, 'Recall': 0.4, 'F1': 0.4000000000000001},
#  'servingSize': {'Precision': 0.6666666666666666,
#   'Recall': 0.5,
#   'F1': 0.5714285714285715},
#  'checkInTime': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'category': {'Precision': 0.5714285714285714,
#   'Recall': 0.5714285714285714,
#   'F1': 0.5714285714285714},
#  'birthPlace': {'Precision': 1.0, 'Recall': 0.5, 'F1': 0.6666666666666666},
#  'address': {'Precision': 0.2727272727272727,
#   'Recall': 0.6,
#   'F1': 0.37499999999999994},
#  'addressLocality': {'Precision': 0.6363636363636364,
#   'Recall': 0.875,
#   'F1': 0.7368421052631579},
#  'nationality': {'Precision': 0.8, 'Recall': 1.0, 'F1': 0.888888888888889},
#  'numberOfPages': {'Precision': 0.6666666666666666,
#   'Recall': 0.8,
#   'F1': 0.7272727272727272},
#  'streetAddress': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'copyrightYear': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'gtin': {'Precision': 0.6, 'Recall': 1.0, 'F1': 0.7499999999999999},
#  'servesCuisine': {'Precision': 0.6666666666666666, 'Recall': 1.0, 'F1': 0.8},
#  'nutrition': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'birthDate': {'Precision': 1.0,
#   'Recall': 0.8571428571428571,
#   'F1': 0.923076923076923},
#  'validFrom': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'duration': {'Precision': 0.8181818181818182,
#   'Recall': 0.8181818181818182,
#   'F1': 0.8181818181818182},
#  'startDate': {'Precision': 0.5, 'Recall': 0.8, 'F1': 0.6153846153846154},
#  'bookFormat': {'Precision': 1.0, 'Recall': 0.5, 'F1': 0.6666666666666666},
#  'material': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'location': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'checkoutTime': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'dateCreated': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'actor': {'Precision': 1.0, 'Recall': 0.2, 'F1': 0.33333333333333337},
#  'givenName': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'price': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'track': {'Precision': 1.0, 'Recall': 0.5, 'F1': 0.6666666666666666},
#  'prepTime': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'email': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'eventAttendanceMode': {'Precision': 0.75, 'Recall': 0.75, 'F1': 0.75},
#  'datePosted': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'homeTeam': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'hiringOrganization': {'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0},
#  'availableDeliveryMethod': {'Precision': 0.3333333333333333,
#   'Recall': 0.5,
#   'F1': 0.4},
#  'model': {'Precision': 1.0, 'Recall': 0.5, 'F1': 0.6666666666666666},
#  'paymentAccepted': {'Precision': 1.0, 'Recall': 0.8, 'F1': 0.888888888888889},
#  'faxNumber': {'Precision': 1.0, 'Recall': 0.3333333333333333, 'F1': 0.5},
#  'addressCountry': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0}}

# %% [markdown]
# ## Error Analysis

# %%
errors = 0
for i in range(len(predictions)):
    if predictions[i] != labels[i]:
        errors += 1
        print(f"Predicted as {predictions[i]} when it was {labels[i]}")
errors
# Out:
# Predicted as description when it was publisher
# Predicted as priceRange when it was price
# Predicted as eventStatus when it was eventAttendanceMode
# Predicted as - when it was organizer
# Predicted as organizer when it was telephone
# Predicted as telephone when it was faxNumber
# Predicted as countryOfOrigin when it was addressCountry
# Predicted as genre when it was actor
# Predicted as performer when it was director
# Predicted as inLanguage when it was actor
# Predicted as performer when it was director
# Predicted as inLanguage when it was category
# Predicted as priceRange when it was price
# Predicted as performer when it was author
# Predicted as performer when it was headline
# Predicted as description when it was text
# Predicted as startDate when it was endDate
# Predicted as endDate when it was startDate
# Predicted as address when it was longitude
# Predicted as address when it was latitude
# Predicted as address when it was ratingValue
# Predicted as address when it was worstRating
# Predicted as address when it was bestRating
# Predicted as address when it was checkoutTime
# Predicted as address when it was checkInTime
# Predicted as addressLocality when it was address
# Predicted as checkInTime when it was checkoutTime
# Predicted as bestRating when it was ratingValue
# Predicted as worstRating when it was bestRating
# Predicted as review when it was worstRating
# Predicted as priceCurrency when it was review
# Predicted as - when it was currenciesAccepted
# Predicted as director when it was actor
# Predicted as releaseDate when it was datePublished
# Predicted as performer when it was director
# Predicted as numTracks when it was bestRating
# Predicted as totalTime when it was worstRating
# Predicted as performer when it was actor
# Predicted as brand when it was productionCompany
# Predicted as inAlbum when it was image
# Predicted as totalTime when it was track
# Predicted as byArtist when it was duration
# Predicted as image when it was byArtist
# Predicted as text when it was familyName
# Predicted as - when it was honorificSuffix
# Predicted as - when it was color
# Predicted as color when it was measurements
# Predicted as - when it was measurements
# Predicted as - when it was measurements
# Predicted as manufacturer when it was unitCode
# Predicted as datePublished when it was releaseDate
# Predicted as recipeCuisine when it was cookingMethod
# Predicted as cookingMethod when it was review
# Predicted as duration when it was cookTime
# Predicted as recipeInstructions when it was recipeCategory
# Predicted as ratingValue when it was servingSize
# Predicted as prepTime when it was cookTime
# Predicted as cookTime when it was prepTime
# Predicted as url when it was eventStatus
# Predicted as location when it was organizer
# Predicted as startDate when it was validFrom
# Predicted as startDate when it was validFrom
# Predicted as startDate when it was validFrom
# Predicted as eventStatus when it was category
# Predicted as addressCountry when it was addressRegion
# Predicted as countryOfOrigin when it was addressCountry
# Predicted as telephone when it was faxNumber
# Predicted as priceCurrency when it was priceRange
# Predicted as telephone when it was faxNumber
# Predicted as addressCountry when it was addressRegion
# Predicted as addressLocality when it was addressRegion
# Predicted as countryOfOrigin when it was addressCountry
# Predicted as releaseDate when it was dateCreated
# Predicted as releaseDate when it was dateCreated
# Predicted as performer when it was actor
# Predicted as datePublished when it was releaseDate
# Predicted as brand when it was category
# Predicted as - when it was weight
# Predicted as description when it was review
# Predicted as organizer when it was location
# Predicted as performer when it was organizer
# Predicted as validFrom when it was startDate
# Predicted as validThrough when it was endDate
# Predicted as publisher when it was location
# Predicted as brand when it was organizer
# Predicted as inLanguage when it was performer
# Predicted as openingHours when it was description
# Predicted as latitude when it was checkInTime
# Predicted as longitude when it was latitude
# Predicted as endDate when it was longitude
# Predicted as startDate when it was checkoutTime
# Predicted as telephone when it was faxNumber
# Predicted as priceCurrency when it was currenciesAccepted
# Predicted as countryOfOrigin when it was addressCountry
# Predicted as ratingValue when it was worstRating
# Predicted as bestRating when it was ratingValue
# Predicted as worstRating when it was bestRating
# Predicted as - when it was amenityFeature
# Predicted as - when it was longitude
# Predicted as countryOfOrigin when it was addressCountry
# Predicted as checkInTime when it was closes
# Predicted as - when it was opens
# Predicted as releaseDate when it was datePublished
# Predicted as bestRating when it was ratingValue
# Predicted as numTracks when it was bestRating
# Predicted as totalTime when it was actor
# Predicted as performer when it was worstRating
# Predicted as releaseDate when it was datePublished
# Predicted as byArtist when it was director
# Predicted as publisher when it was productionCompany
# Predicted as worstRating when it was ratingValue
# Predicted as datePublished when it was birthDate
# Predicted as endDate when it was deathDate
# Predicted as dateCreated when it was releaseDate
# Predicted as - when it was servingSize
# Predicted as servingSize when it was nutrition
# Predicted as weight when it was nutrition
# Predicted as prepTime when it was nutrition
# Predicted as cookTime when it was nutrition
# Predicted as totalTime when it was nutrition
# Predicted as - when it was nutrition
# Predicted as recipeCategory when it was prepTime
# Predicted as recipeCuisine when it was nutrition
# Predicted as recipeInstructions when it was nutrition
# Predicted as duration when it was recipeIngredient
# Predicted as eventStatus when it was cookTime
# Predicted as suitableForDiet when it was recipeCategory
# Predicted as - when it was totalTime
# Predicted as nutrition when it was recipeCuisine
# Predicted as eventAttendanceMode when it was recipeInstructions
# Predicted as amenityFeature when it was nutrition
# Predicted as - when it was worstRating
# Predicted as numberOfPages when it was bestRating
# Predicted as ratingValue when it was review
# Predicted as description when it was review
# Predicted as priceRange when it was price
# Predicted as priceRange when it was price
# Predicted as releaseDate when it was datePublished
# Predicted as itemCondition when it was author
# Predicted as priceRange when it was price
# Predicted as - when it was inLanguage
# Predicted as category when it was genre
# Predicted as releaseDate when it was datePublished
# Predicted as category when it was genre
# Predicted as releaseDate when it was datePublished
# Predicted as category when it was genre
# Predicted as addressRegion when it was addressLocality
# Predicted as url when it was bookFormat
# Predicted as gtin when it was isbn
# Predicted as datePublished when it was copyrightYear
# Predicted as priceRange when it was price
# Predicted as brand when it was author
# Predicted as performer when it was headline
# Predicted as description when it was text
# Predicted as countryOfOrigin when it was addressCountry
# Predicted as bestRating when it was ratingValue
# Predicted as releaseDate when it was datePublished
# Predicted as releaseDate when it was datePublished
# Predicted as performer when it was actor
# Predicted as addressLocality when it was birthPlace
# Predicted as brand when it was manufacturer
# Predicted as manufacturer when it was image
# Predicted as prepTime when it was totalTime
# Predicted as suitableForDiet when it was prepTime
# Predicted as cookTime when it was totalTime
# Predicted as servesCuisine when it was recipeCuisine
# Predicted as inLanguage when it was isbn
# Predicted as isbn when it was numberOfPages
# Predicted as numberOfPages when it was inLanguage
# Predicted as availableLanguage when it was bookFormat
# Predicted as availableLanguage when it was inLanguage
# Predicted as availableDeliveryMethod when it was availability
# Predicted as datePosted when it was validFrom
# Predicted as organizer when it was location
# Predicted as address when it was location
# Predicted as startDate when it was validThrough
# Predicted as performer when it was organizer
# Predicted as endDate when it was validFrom
# Predicted as ratingValue when it was price
# Predicted as - when it was location
# Predicted as releaseDate when it was dateCreated
# Predicted as addressLocality when it was address
# Predicted as - when it was location
# Predicted as datePublished when it was datePosted
# Predicted as startDate when it was datePosted
# Predicted as startDate when it was datePosted
# Predicted as checkInTime when it was opens
# Predicted as addressCountry when it was addressRegion
# Predicted as - when it was closes
# Predicted as ratingValue when it was bestRating
# Predicted as performer when it was actor
# Predicted as performer when it was byArtist
# Predicted as totalTime when it was duration
# Predicted as inAlbum when it was byArtist
# Predicted as byArtist when it was inAlbum
# Predicted as - when it was inAlbum
# Predicted as manufacturer when it was inAlbum
# Predicted as - when it was model
# Predicted as itemCondition when it was unitCode
# Predicted as itemCondition when it was unitCode
# Predicted as itemCondition when it was unitCode
# Predicted as ratingValue when it was measurements
# Predicted as ratingValue when it was measurements
# Predicted as ratingValue when it was measurements
# Predicted as gtin when it was productID
# Predicted as priceRange when it was price
# Predicted as - when it was productID
# Predicted as - when it was productID
# Predicted as - when it was availableDeliveryMethod
# Predicted as availableDeliveryMethod when it was paymentAccepted
# Predicted as - when it was productID
# Predicted as unitCode when it was unitText
# Predicted as nationality when it was recipeCuisine
# Predicted as numTracks when it was episodeNumber
# Predicted as inLanguage when it was partOfSeries
# 215

# %% [markdown]
# ### Re-load previous preds files

# %%
with open(f'Predictions/{model_name}/table/{nr}-shot/chat-table-{prompt_name}-{nr}-shot.pkl', "rb") as f:
    preds = pickle.load(f)

# %%
with open(f'Predictions/{model_name}/table/zero-shot/chat-table-r2-zero-shot.pkl', "rb") as f:
    preds = pickle.load(f)

# %%
preds
# Out:
# ['Column 2: manufacturer\nColumn 3: availability\nColumn 4: price',
#  'Column 2: event title\nColumn 3: event details',
#  'Column 2: headline\nColumn 3: organizer\nColumn 4: email',
#  'Column 2: contact number\nColumn 3: address country\nColumn 4: postal code',
#  'Column 2: director\nColumn 3: performer\nColumn 4: image',
#  'Column 2: rating value\nColumn 3: content rating\nColumn 4: genre\nColumn 5: director',
#  'Column 2: nationality\nColumn 3: job title',
#  'Column 2: birth date\nColumn 3: gender\nColumn 4: job title',
#  'Column 2: job title\nColumn 3: telephone\nColumn 4: gender',
#  'Column 2: description\nColumn 3: in album\nColumn 4: item condition',
#  'Column 2: author\nColumn 3: price currency\nColumn 4: publisher\nColumn 5: item condition\nColumn 6: price',
#  'Column 2: author\nColumn 3: description\nColumn 4: headline',
#  'Column 2: start date\nColumn 3: location\nColumn 4: event attendance mode\nColumn 5: valid from\nColumn 6: event status',
#  'Column 2: description, Column 3: description, Column 4: description, Column 5: description, Column 6: description, Column 7: description, Column 8: description, Column 9: location',
#  'Column 2: check-in time\nColumn 3: in language\nColumn 4: price',
#  'Column 2: brand\nColumn 3: opening hours\nColumn 4: image\nColumn 5: email',
#  'Column 2: availability\nColumn 3: rating value\nColumn 4: best rating\nColumn 5: review\nColumn 6: price currency',
#  'Column 2: duration\nColumn 3: content rating\nColumn 4: production company',
#  'Column 2: director\nColumn 3: duration\nColumn 4: release date\nColumn 5: content rating\nColumn 6: performer\nColumn 7: rating value\nColumn 8: best rating\nColumn 9: episode number',
#  'Column 2: description\nColumn 3: performer\nColumn 4: production company',
#  'Column 2: image, Column 3: number of tracks, Column 4: duration, Column 5: by artist',
#  'Column 2: email\nColumn 3: gender',
#  'Column 2: job title\nColumn 3: alma mater\nColumn 4: honorific suffix',
#  'Column 2: product ID\nColumn 3: color\nColumn 4: width\nColumn 5: height\nColumn 6: weight',
#  'Column 2: manufacturer\nColumn 3: date posted',
#  'Column 2: recipe instructions\nColumn 3: recipe instructions\nColumn 4: recipe instructions',
#  'Column 2: cooking method\nColumn 3: prep time',
#  'Column 2: recipe instructions\nColumn 3: recipe category\nColumn 4: rating value\nColumn 5: total time\nColumn 6: prep time\nColumn 7: suitable for diet',
#  'Column 2: start date\nColumn 3: end date\nColumn 4: organizer\nColumn 5: event status',
#  'Column 2: start date\nColumn 3: location\nColumn 4: end date',
#  'Column 2: start date\nColumn 3: event attendance mode\nColumn 4: event status',
#  'Column 2: start date\nColumn 3: event status\nColumn 4: organizer\nColumn 5: email',
#  'Column 2: price\nColumn 3: region of address\nColumn 4: address country\nColumn 5: locality of address\nColumn 6: street address',
#  'Column 2: telephone\nColumn 3: fax number\nColumn 4: postal code\nColumn 5: street address\nColumn 6: price currency',
#  'Column 2: telephone\nColumn 3: telephone\nColumn 4: street address\nColumn 5: address country\nColumn 6: locality of address\nColumn 7: postal code',
#  'Column 2: telephone\nColumn 3: fax number\nColumn 4: region of address\nColumn 5: locality of address\nColumn 6: address country',
#  'Column 2: date published, Column 3: duration, Column 4: director, Column 5: actor',
#  'Column 2: episode number\nColumn 3: date published\nColumn 4: by artist',
#  'Column 2: date created\nColumn 3: item condition\nColumn 4: product ID',
#  'Column 2: valid from\nColumn 3: organizer',
#  'Column 2: product ID',
#  'Column 2: product ID\nColumn 3: date posted\nColumn 4: description',
#  'Column 2: start date\nColumn 3: end date\nColumn 4: location\nColumn 5: organizer',
#  'Column 2: valid from\nColumn 3: valid through\nColumn 4: manufacturer\nColumn 5: brand\nColumn 6: in language\nColumn 7: event status\nColumn 8: event attendance mode',
#  'Column 2: telephone\nColumn 3: address\nColumn 4: description\nColumn 5: check-in time\nColumn 6: latitude\nColumn 7: longitude\nColumn 8: check-out time',
#  'Column 2: telephone\nColumn 3: fax number\nColumn 4: price range\nColumn 5: url\nColumn 6: payment accepted\nColumn 7: price currency\nColumn 8: postal code\nColumn 9: address country\nColumn 10: locality of address\nColumn 11: street address\nColumn 12: description\nColumn 13: best rating\nColumn 14: rating value\nColumn 15: latitude',
#  'Column 2: telephone\nColumn 3: address country\nColumn 4: day of week\nColumn 5: closes\nColumn 6: opens\nColumn 7: region of address',
#  'Column 2: duration\nColumn 3: release date\nColumn 4: content rating\nColumn 5: director\nColumn 6: best rating\nColumn 7: worst rating\nColumn 8: actor\nColumn 9: episode number',
#  'Column 2: release date\nColumn 3: in language\nColumn 4: performer\nColumn 5: image\nColumn 6: url\nColumn 7: publisher\nColumn 8: best rating\nColumn 9: rating value',
#  'Column 2: date created\nColumn 3: date posted\nColumn 4: given name\nColumn 5: family name\nColumn 6: gender',
#  'Column 2: birth date\nColumn 3: death date\nColumn 4: description',
#  'Column 2: height\nColumn 3: nationality\nColumn 4: birth date\nColumn 5: birth place',
#  'Column 2: weight\nColumn 3: date created',
#  'Column 2: serving size, Column 3: weight, Column 4: calories, Column 5: fat, Column 6: protein, Column 7: carbohydrates, Column 8: ingredients, Column 9: prep time, Column 10: sodium, Column 11: calories, Column 12: prep time, Column 13: category, Column 14: total time, Column 15: cuisine',
#  'Column 2: category\nColumn 3: best rating\nColumn 4: review',
#  'Column 2: suitable for occasion',
#  'Column 2: location\nColumn 3: amenity feature',
#  'Column 2: locality of address\nColumn 3: street address',
#  'Column 2: isbn\nColumn 3: publisher',
#  'Column 2: price\nColumn 3: price currency\nColumn 4: author\nColumn 5: availability',
#  'Column 2: price currency\nColumn 3: author\nColumn 4: availability\nColumn 5: price',
#  'Column 2: date posted\nColumn 3: price currency\nColumn 4: genre\nColumn 5: price\nColumn 6: availability',
#  'Column 2: in language\nColumn 3: publisher\nColumn 4: isbn\nColumn 5: book format\nColumn 6: author\nColumn 7: number of pages\nColumn 8: category',
#  'Column 2: date published\nColumn 3: author\nColumn 4: publisher\nColumn 5: isbn\nColumn 6: url\nColumn 7: category',
#  'Column 2: release date\nColumn 3: description\nColumn 4: author\nColumn 5: url\nColumn 6: category',
#  'Column 2: job title\nColumn 3: image\nColumn 4: description\nColumn 5: email',
#  'Column 2: postal code\nColumn 3: gender\nColumn 4: locality of address',
#  'Column 2: number of pages\nColumn 3: publisher\nColumn 4: book format\nColumn 5: author\nColumn 6: product ID',
#  'Column 2: isbn\nColumn 3: copyright year\nColumn 4: number of pages',
#  'Column 2: price currency, Column 3: book edition, Column 4: availability, Column 5: price, Column 6: author',
#  'Column 2: performer\nColumn 3: publisher\nColumn 4: headline\nColumn 5: date published',
#  'Column 2: location\nColumn 3: price range\nColumn 4: country of origin',
#  'Column 2: fax number\nColumn 3: description\nColumn 4: payment accepted\nColumn 5: best rating\nColumn 6: rating value',
#  'Column 2: release date\nColumn 3: director\nColumn 4: performer',
#  'Column 2: date published\nColumn 3: director\nColumn 4: duration\nColumn 5: performer',
#  'Column 2: performer\nColumn 3: nationality',
#  'Column 2: nationality\nColumn 3: gender\nColumn 4: birth date',
#  'Column 2: job title\nColumn 3: birth date\nColumn 4: nationality',
#  'Column 2: job title\nColumn 3: given name\nColumn 4: family name',
#  'Column 2: family name\nColumn 3: given name\nColumn 4: death date\nColumn 5: location\nColumn 6: birth date',
#  'Column 2: brand\nColumn 3: image\nColumn 4: unit text',
#  'Column 2: color\nColumn 3: item condition\nColumn 4: material\nColumn 5: brand',
#  'Column 2: recipe name\nColumn 3: recipe cuisine\nColumn 4: recipe ingredient\nColumn 5: prep time\nColumn 6: recipe category\nColumn 7: total time\nColumn 8: recipe instructions',
#  'Column 2: total time\nColumn 3: recipe ingredient\nColumn 4: recipe category\nColumn 5: prep time\nColumn 6: nationality\nColumn 7: recipe cuisine',
#  'Column 2: suitable for diet\nColumn 3: gtin\nColumn 4: number of pages\nColumn 5: in language',
#  'Column 2: publisher\nColumn 3: isbn\nColumn 4: author\nColumn 5: book format\nColumn 6: number of pages\nColumn 7: in language',
#  'Column 2: isbn\nColumn 3: item condition\nColumn 4: available delivery method',
#  'Column 2: start date\nColumn 3: event status\nColumn 4: price currency\nColumn 5: valid from\nColumn 6: location\nColumn 7: description',
#  'Column 2: start date\nColumn 3: location\nColumn 4: end date',
#  'Column 2: event status\nColumn 3: organizer\nColumn 4: date created',
#  'Column 2: start date\nColumn 3: in language\nColumn 4: best rating\nColumn 5: end date',
#  'Column 2: url\nColumn 3: location\nColumn 4: image',
#  'Column 2: content rating\nColumn 3: release date',
#  'Column 2: start date\nColumn 3: end date\nColumn 4: headline\nColumn 5: location\nColumn 6: venue',
#  'Column 2: date posted\nColumn 3: job title\nColumn 4: url\nColumn 5: hiring organization',
#  'Column 2: start date, Column 3: job title, Column 4: hiring organization, Column 5: employment type',
#  'Column 2: date posted\nColumn 3: job title\nColumn 4: employment type\nColumn 5: hiring organization',
#  'Column 2: telephone,\nColumn 3: email,\nColumn 4: locality of address,\nColumn 5: street address,\nColumn 6: postal code,\nColumn 7: longitude,\nColumn 8: latitude,\nColumn 9: day of week,\nColumn 10: check-in time,\nColumn 11: region of address,\nColumn 12: check-out time',
#  'Column 2: production company\nColumn 3: genre\nColumn 4: rating value\nColumn 5: actor',
#  'Column 2: nationality\nColumn 3: director',
#  'Column 2: number of tracks\nColumn 3: performer\nColumn 4: in album\nColumn 5: duration\nColumn 6: track',
#  'Column 2: duration\nColumn 3: part of series\nColumn 4: headline',
#  'Column 2: duration\nColumn 3: performer\nColumn 4: album',
#  'Column 2: duration\nColumn 3: album\nColumn 4: by artist',
#  'Column 2: duration\nColumn 3: genre\nColumn 4: by artist\nColumn 5: in album',
#  'Column 2: honorific suffix\nColumn 3: given name\nColumn 4: family name',
#  'Column 2: alma mater\nColumn 3: gender',
#  'Column 2: product ID\nColumn 3: gtin\nColumn 4: color\nColumn 5: material\nColumn 6: item condition\nColumn 7: availability\nColumn 8: price\nColumn 9: weight\nColumn 10: price currency\nColumn 11: category\nColumn 12: brand',
#  'Column 2: model\nColumn 3: color\nColumn 4: item condition',
#  'Column 2: item condition\nColumn 3: product ID\nColumn 4: price\nColumn 5: manufacturer\nColumn 6: date posted',
#  'Column 2: available delivery method\nColumn 3: product ID\nColumn 4: category',
#  'Column 2: gtin\nColumn 3: brand\nColumn 4: product ID',
#  'Column 2: available delivery method\nColumn 3: payment accepted',
#  'Column 2: material\nColumn 3: weight\nColumn 4: product ID',
#  'Column 2: material\nColumn 3: manufacturer',
#  'Column 2: unit text\nColumn 3: gtin',
#  'Column 2: cooking method\nColumn 3: serving size',
#  'Column 2: recipe instructions\nColumn 3: suitable for diet\nColumn 4: serving size',
#  'Column 2: opening hours, Column 3: payment accepted, Column 4: serves cuisine',
#  'Column 2: opening hours\nColumn 3: payment accepted\nColumn 4: serves cuisine',
#  'Column 2: home team\nColumn 3: away team\nColumn 4: date published',
#  'Column 2: start date\nColumn 3: home team\nColumn 4: away team',
#  'Column 2: episode number\nColumn 3: description\nColumn 4: part of series',
#  'Column 2: url\nColumn 3: by artist',
#  'Column 2: episode number\nColumn 3: description\nColumn 4: part of series']
